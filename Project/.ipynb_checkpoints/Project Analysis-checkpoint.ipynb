# %%
import pandas as pd
from pandas import DataFrame, Series

import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#df1 = pd.read_csv('dems.csv')
#df = df1[['created_at','tweet','user']]
df = pd.read_csv('candidates.csv')

#df = df.append(cand)
df['user'].nunique()
# Out:
# 3903

# %%
#creating original_creator 
def original(tweet): 
    if tweet.split()[0] == 'RT': 
        return tweet.split()[1][1:-1]
    return 'AAA' 

df['original_creator'] = df['tweet'].map(original)

def retweet(tweet): 
    if tweet.split()[0] == 'RT': 
        return 1
    return 0 

df['retweet'] = df['tweet'].map(retweet)

def get_tweets(tweet):
    sentence = " "
    new_tweet = tweet.split()[2:]
    for x in new_tweet:
        x = x + ' '
        sentence += x
    return sentence 

df['tweet'] = df['tweet'].map(get_tweets)

# %%
t = df
ori = t[t['original_creator'] == 'AAA']
rt = t[t['original_creator'] != 'AAA']

ori['original_creator'] = ori['user']
ori_and_rt = ori.append(rt)

# %%
df2 = ori_and_rt.copy()
df2['original_creator'].nunique()
# Out:
# 1315

# %%
degrees = df2['original_creator'].value_counts()[:200].index
def degree_filter(name): 
    if name in degrees: 
        return 1 
    return 0 

df2['degrees'] = df2['original_creator'].map(degree_filter)
df2 = df2[df2['degrees'] == 1]

# %% [markdown]
# Network Structure

# %%
import networkx as nx
# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df2,
    source = 'user', 
    target = 'original_creator',
    create_using = nx.DiGraph())

# %%
def assign_candidate(tweet): 
    tweet = tweet.lower()
    if '#berniesanders'in tweet: 
        return 1.25
    if '#joebiden'in tweet: 
        return 1.0
    if '#mikebloomberg'in tweet: 
        return .75
    if '#petebuttigieg'in tweet: 
        return .5
    if '#elizabethwarren' in tweet: 
        return 0.25
    return 0.0

df2['value'] = df2['tweet'].map(assign_candidate)

# %%
val_map = dict(zip(df2.user, df2.value))
values = [val_map.get(node, .25) for node in network.nodes()]

# %%
print('Nodes in RT network:', len(network.nodes()))
print('Edges in RT network:', len(network.edges()))
# Out:
# Nodes in RT network: 2744
# Edges in RT network: 2917

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, cmap=plt.get_cmap('viridis'),node_color=values)
plt.title('Retweet to Tweet Flow Chart', size=15)
plt.show()

# %% [markdown]
# Network Centrality, closeness, and betweeness

# %%
graph_centrality = nx.degree_centrality(network)
sorted_cent = sorted(graph_centrality.items(), key=lambda x: x[1], reverse=True)
DataFrame(sorted_cent).head()
# Out:
#                0         1
# 0     SallyDeal4  0.107546
# 1     larryelder  0.096245
# 2      mayawiley  0.061611
# 3  ResisterSis20  0.053956
# 4    FIGHT_2_KAG  0.029894

# %%
graph_closeness = nx.closeness_centrality(network)
sorted_closeness = sorted(graph_closeness.items(), key=lambda x: x[1], reverse=True)
DataFrame(sorted_closeness).head()
# Out:
#                0         1
# 0     SallyDeal4  0.106472
# 1     larryelder  0.096245
# 2  ResisterSis20  0.093533
# 3      mayawiley  0.061611
# 4    FIGHT_2_KAG  0.029165

# %%
graph_betweenness = nx.betweenness_centrality(network, normalized=True, endpoints=False)
sorted_bet=sorted(graph_betweenness.items(), key=lambda x: x[1], reverse=True)[:50]

# %%
DataFrame(sorted_bet)[:5]
# Out:
#               0         1
# 0    SallyDeal4  0.000037
# 1  Readers4Pete  0.000005
# 2   roscoe_p_ny  0.000004
# 3   patrickcurl  0.000002
# 4   Twitlertwit  0.000001

# %%
df2['closeness'] = df['original_creator'].map(graph_closeness)
df2['centrality'] = df['original_creator'].map(graph_centrality)
df2['betweeness']=df['original_creator'].map(graph_betweenness)

# %%
df2.sort_values(by = 'betweeness', ascending=False).head()
# Out:
#       Unnamed: 0             user         location  \
# 1578         604  urbanjackattack    Missouri, USA
# 1157         174       BYourself9      New Zealand
# 1162         179    VoteBlueNoRU1    Michigan, USA
# 1164         181   TexasNewsHound          Houston
# 1771         797           ss5726  North Coast CLE
#
#                                                   tweet           created_at  \
# 1578   We MUST #FlipTheSenate? Agree? 🤔FOOD FOR THOU...  2020-02-19 17:49:40
# 1157   @JoeBiden Speaking of "records", voters shoul...  2020-02-19 21:23:14
# 1162   @JoeBiden Speaking of "records", voters shoul...  2020-02-19 21:20:27
# 1164   @JoeBiden Speaking of "records", voters shoul...  2020-02-19 21:19:40
# 1771   We MUST #FlipTheSenate? Agree? 🤔FOOD FOR THOU...  2020-02-19 15:25:42
#
#      original_creator  retweet  degrees  value  closeness  centrality  \
# 1578       SallyDeal4        1        1    0.0   0.106472    0.107546
# 1157       SallyDeal4        1        1    0.0   0.106472    0.107546
# 1162       SallyDeal4        1        1    0.0   0.106472    0.107546
# 1164       SallyDeal4        1        1    0.0   0.106472    0.107546
# 1771       SallyDeal4        1        1    0.0   0.106472    0.107546
#
#       betweeness
# 1578    0.000037
# 1157    0.000037
# 1162    0.000037
# 1164    0.000037
# 1771    0.000037

# %%
a_list = []
for x in range(0,len(sorted_bet)): 
    b = str(sorted_cent[x][0])
    a_list.append(b)

# %%
def v(name): 
    if name in a_list: 
        return 1 
    return 0 

one_two = df['original_creator'].map(v)
df['top_50'] = one_two
top = df[df['top_50'] == 1]

# %%
non_duplicates = df2['original_creator'].value_counts()
df3=df2[df2['original_creator'].isin(non_duplicates[non_duplicates].index)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/core/series.py in _get_values(self, indexer)
#    1179             return self._constructor(
# -> 1180                 self._data.get_slice(indexer), fastpath=True
#    1181             ).__finalize__(self)
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/core/internals/managers.py in get_slice(self, slobj, axis)
#    1545         return self.__class__(
# -> 1546             self._block._slice(slobj), self.index[slobj], fastpath=True
#    1547         )
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _slice(self, slicer)
#     316         """ return a slice of my values """
# --> 317         return self.values[slicer]
#     318
#
# IndexError: index 335 is out of bounds for axis 0 with size 200
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-2d565a05c08c> in <module>
#       1 non_duplicates = df2['original_creator'].value_counts()
# ----> 2 df3=df2[df2['original_creator'].isin(non_duplicates[non_duplicates].index)]
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1108             key = check_bool_indexer(self.index, key)
#    1109
# -> 1110         return self._get_with(key)
#    1111
#    1112     def _get_with(self, key):
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/core/series.py in _get_with(self, key)
#    1143                 return self.loc[key]
#    1144             else:
# -> 1145                 return self._get_values(key)
#    1146         elif key_type == "boolean":
#    1147             return self._get_values(key)
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/core/series.py in _get_values(self, indexer)
#    1181             ).__finalize__(self)
#    1182         except Exception:
# -> 1183             return self._values[indexer]
#    1184
#    1185     def __setitem__(self, key, value):
#
# IndexError: index 335 is out of bounds for axis 0 with size 200

# %%
# Create retweet network from edgelist
G_rt1 = nx.from_pandas_edgelist(
    df3,
    source = 'user', 
    target = 'original_creator',
    create_using = nx.DiGraph())
    
# Print the number of nodes
print('Nodes in RT network:', len(G_rt1.nodes()))

# Print the number of edges
print('Edges in RT network:', len(G_rt1.edges()))

import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
nx.draw(G_rt1, node_color="red", cmap=plt.cm.PiYG, edge_color="black", linewidths=0.3, node_size=60, alpha=0.6, with_labels=False)
plt.title('Retweet to Tweet Flow Chart', size=20)
plt.show()

# %%
df2
# Out:
#       Unnamed: 0             user                    location  \
# 1              1     LeftSideKrew  The Beltway Washington, DC
# 9              9     LeftSideKrew  The Beltway Washington, DC
# 15            15     LeftSideKrew  The Beltway Washington, DC
# 19            19     LeftSideKrew  The Beltway Washington, DC
# 27            27     LeftSideKrew  The Beltway Washington, DC
# ...          ...              ...                         ...
# 4767         995  Tommy_Blackjack                         NaN
# 4768         996     ButlerRunner                 Phoenix, AZ
# 4769         997      gilldaniels                      Boston
# 4770         998          mrcrom1                         NaN
# 4771         999       gilajoanne             Silver City, NM
#
#                                                   tweet           created_at  \
# 1      On Bloomberg 'Already Right Wing Racist Misog...  2020-02-19 22:25:39
# 9      Calls Out Billionaire Oligarchs Michael Bloom...  2020-02-19 22:25:02
# 15     and The Black Vote https://t.co/0H5nfUE7Vf #B...  2020-02-19 22:24:14
# 19     West Arrested in 2011 For Protesting Against ...  2020-02-19 22:23:54
# 27     West Explains Why Brother Bernie Sanders Beat...  2020-02-19 22:23:20
# ...                                                 ...                  ...
# 4767   Why no one should sell #ElizabethWarren short...  2020-02-19 14:58:48
# 4768   Why no one should sell #ElizabethWarren short...  2020-02-19 14:58:46
# 4769   Why no one should sell #ElizabethWarren short...  2020-02-19 14:58:00
# 4770   Why no one should sell #ElizabethWarren short...  2020-02-19 14:57:35
# 4771   Good morning, Twitter friends and #TeamWarren...  2020-02-19 14:57:01
#
#      original_creator  retweet  degrees  value
# 1        LeftSideKrew        0        1   1.25
# 9        LeftSideKrew        0        1   1.25
# 15       LeftSideKrew        0        1   1.25
# 19       LeftSideKrew        0        1   1.25
# 27       LeftSideKrew        0        1   1.25
# ...               ...      ...      ...    ...
# 4767        mayawiley        1        1   0.25
# 4768        mayawiley        1        1   0.25
# 4769        mayawiley        1        1   0.25
# 4770        mayawiley        1        1   0.25
# 4771     POCForWarren        1        1   0.00
#
# [3335 rows x 9 columns]

# %%
df2['tweet']=df2['tweet'].str.lower()
df2['hashtag']=df2['tweet'].str.findall(r'#.*?(?=\s|$)')

# %%
df2['hashtag']=df2['hashtag'].astype(str)

# %%
import numpy as np
df2['Warren']=np.where(df2['hashtag'].str.contains('war'), 1, 0)
df2['Bernie']=np.where(df2['hashtag'].str.contains('ber'), 1, 0)
df2['Biden']=np.where(df2['hashtag'].str.contains('bi'), 1, 0)
df2['Pete']=np.where(df2['hashtag'].str.contains('pete'), 1, 0)
df2['Bloomberg']=np.where(df2['hashtag'].str.contains('bloom'), 1, 0)

# %%
df2
# Out:
#       Unnamed: 0             user                    location  \
# 1              1     LeftSideKrew  The Beltway Washington, DC
# 9              9     LeftSideKrew  The Beltway Washington, DC
# 15            15     LeftSideKrew  The Beltway Washington, DC
# 19            19     LeftSideKrew  The Beltway Washington, DC
# 27            27     LeftSideKrew  The Beltway Washington, DC
# ...          ...              ...                         ...
# 4767         995  Tommy_Blackjack                         NaN
# 4768         996     ButlerRunner                 Phoenix, AZ
# 4769         997      gilldaniels                      Boston
# 4770         998          mrcrom1                         NaN
# 4771         999       gilajoanne             Silver City, NM
#
#                                                   tweet           created_at  \
# 1      on bloomberg 'already right wing racist misog...  2020-02-19 22:25:39
# 9      calls out billionaire oligarchs michael bloom...  2020-02-19 22:25:02
# 15     and the black vote https://t.co/0h5nfue7vf #b...  2020-02-19 22:24:14
# 19     west arrested in 2011 for protesting against ...  2020-02-19 22:23:54
# 27     west explains why brother bernie sanders beat...  2020-02-19 22:23:20
# ...                                                 ...                  ...
# 4767   why no one should sell #elizabethwarren short...  2020-02-19 14:58:48
# 4768   why no one should sell #elizabethwarren short...  2020-02-19 14:58:46
# 4769   why no one should sell #elizabethwarren short...  2020-02-19 14:58:00
# 4770   why no one should sell #elizabethwarren short...  2020-02-19 14:57:35
# 4771   good morning, twitter friends and #teamwarren...  2020-02-19 14:57:01
#
#      original_creator  retweet  degrees  value  \
# 1        LeftSideKrew        0        1   1.25
# 9        LeftSideKrew        0        1   1.25
# 15       LeftSideKrew        0        1   1.25
# 19       LeftSideKrew        0        1   1.25
# 27       LeftSideKrew        0        1   1.25
# ...               ...      ...      ...    ...
# 4767        mayawiley        1        1   0.25
# 4768        mayawiley        1        1   0.25
# 4769        mayawiley        1        1   0.25
# 4770        mayawiley        1        1   0.25
# 4771     POCForWarren        1        1   0.00
#
#                                                 hashtag  Warren  Bernie  \
# 1     ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 9     ['#hellosomebody', '#bernie', '#berniesanders'...       1       1
# 15    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 19    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 27    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# ...                                                 ...     ...     ...
# 4767          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4768          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4769          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4770          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4771                                   ['#teamwarren!']       1       0
#
#       Biden  Pete  Bloomberg
# 1         1     1          1
# 9         1     1          1
# 15        1     1          1
# 19        1     1          1
# 27        1     1          1
# ...     ...   ...        ...
# 4767      0     0          1
# 4768      0     0          1
# 4769      0     0          1
# 4770      0     0          1
# 4771      0     0          0
#
# [3335 rows x 15 columns]

# %%
df2['Pete'].value_counts()
# Out:
# 0    2897
# 1     438
# Name: Pete, dtype: int64

# %%
Warren = df2[df2['Warren']==1]
Bernie = df2[df2['Bernie']==1]
Biden = df2[df2['Biden']==1]
Pete = df2[df2['Pete']==1]
Bloomberg = df2[df2['Bloomberg']==1]

# %%
Warren
# Out:
#       Unnamed: 0             user                    location  \
# 1              1     LeftSideKrew  The Beltway Washington, DC
# 9              9     LeftSideKrew  The Beltway Washington, DC
# 15            15     LeftSideKrew  The Beltway Washington, DC
# 19            19     LeftSideKrew  The Beltway Washington, DC
# 27            27     LeftSideKrew  The Beltway Washington, DC
# ...          ...              ...                         ...
# 4767         995  Tommy_Blackjack                         NaN
# 4768         996     ButlerRunner                 Phoenix, AZ
# 4769         997      gilldaniels                      Boston
# 4770         998          mrcrom1                         NaN
# 4771         999       gilajoanne             Silver City, NM
#
#                                                   tweet           created_at  \
# 1      on bloomberg 'already right wing racist misog...  2020-02-19 22:25:39
# 9      calls out billionaire oligarchs michael bloom...  2020-02-19 22:25:02
# 15     and the black vote https://t.co/0h5nfue7vf #b...  2020-02-19 22:24:14
# 19     west arrested in 2011 for protesting against ...  2020-02-19 22:23:54
# 27     west explains why brother bernie sanders beat...  2020-02-19 22:23:20
# ...                                                 ...                  ...
# 4767   why no one should sell #elizabethwarren short...  2020-02-19 14:58:48
# 4768   why no one should sell #elizabethwarren short...  2020-02-19 14:58:46
# 4769   why no one should sell #elizabethwarren short...  2020-02-19 14:58:00
# 4770   why no one should sell #elizabethwarren short...  2020-02-19 14:57:35
# 4771   good morning, twitter friends and #teamwarren...  2020-02-19 14:57:01
#
#      original_creator  retweet  degrees  value  \
# 1        LeftSideKrew        0        1   1.25
# 9        LeftSideKrew        0        1   1.25
# 15       LeftSideKrew        0        1   1.25
# 19       LeftSideKrew        0        1   1.25
# 27       LeftSideKrew        0        1   1.25
# ...               ...      ...      ...    ...
# 4767        mayawiley        1        1   0.25
# 4768        mayawiley        1        1   0.25
# 4769        mayawiley        1        1   0.25
# 4770        mayawiley        1        1   0.25
# 4771     POCForWarren        1        1   0.00
#
#                                                 hashtag  Warren  Bernie  \
# 1     ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 9     ['#hellosomebody', '#bernie', '#berniesanders'...       1       1
# 15    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 19    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 27    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# ...                                                 ...     ...     ...
# 4767          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4768          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4769          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4770          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4771                                   ['#teamwarren!']       1       0
#
#       Biden  Pete  Bloomberg
# 1         1     1          1
# 9         1     1          1
# 15        1     1          1
# 19        1     1          1
# 27        1     1          1
# ...     ...   ...        ...
# 4767      0     0          1
# 4768      0     0          1
# 4769      0     0          1
# 4770      0     0          1
# 4771      0     0          0
#
# [603 rows x 15 columns]

# %%
Bernie
# Out:
#       Unnamed: 0             user                    location  \
# 1              1     LeftSideKrew  The Beltway Washington, DC
# 9              9     LeftSideKrew  The Beltway Washington, DC
# 15            15     LeftSideKrew  The Beltway Washington, DC
# 19            19     LeftSideKrew  The Beltway Washington, DC
# 27            27     LeftSideKrew  The Beltway Washington, DC
# ...          ...              ...                         ...
# 4766         994           jdar57                         NaN
# 4767         995  Tommy_Blackjack                         NaN
# 4768         996     ButlerRunner                 Phoenix, AZ
# 4769         997      gilldaniels                      Boston
# 4770         998          mrcrom1                         NaN
#
#                                                   tweet           created_at  \
# 1      on bloomberg 'already right wing racist misog...  2020-02-19 22:25:39
# 9      calls out billionaire oligarchs michael bloom...  2020-02-19 22:25:02
# 15     and the black vote https://t.co/0h5nfue7vf #b...  2020-02-19 22:24:14
# 19     west arrested in 2011 for protesting against ...  2020-02-19 22:23:54
# 27     west explains why brother bernie sanders beat...  2020-02-19 22:23:20
# ...                                                 ...                  ...
# 4766   why no one should sell #elizabethwarren short...  2020-02-19 14:59:32
# 4767   why no one should sell #elizabethwarren short...  2020-02-19 14:58:48
# 4768   why no one should sell #elizabethwarren short...  2020-02-19 14:58:46
# 4769   why no one should sell #elizabethwarren short...  2020-02-19 14:58:00
# 4770   why no one should sell #elizabethwarren short...  2020-02-19 14:57:35
#
#      original_creator  retweet  degrees  value  \
# 1        LeftSideKrew        0        1   1.25
# 9        LeftSideKrew        0        1   1.25
# 15       LeftSideKrew        0        1   1.25
# 19       LeftSideKrew        0        1   1.25
# 27       LeftSideKrew        0        1   1.25
# ...               ...      ...      ...    ...
# 4766        mayawiley        1        1   0.25
# 4767        mayawiley        1        1   0.25
# 4768        mayawiley        1        1   0.25
# 4769        mayawiley        1        1   0.25
# 4770        mayawiley        1        1   0.25
#
#                                                 hashtag  Warren  Bernie  \
# 1     ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 9     ['#hellosomebody', '#bernie', '#berniesanders'...       1       1
# 15    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 19    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 27    ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# ...                                                 ...     ...     ...
# 4766          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4767          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4768          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4769          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4770          ['#elizabethwarren', '#michaelbloomberg']       1       1
#
#       Biden  Pete  Bloomberg
# 1         1     1          1
# 9         1     1          1
# 15        1     1          1
# 19        1     1          1
# 27        1     1          1
# ...     ...   ...        ...
# 4766      0     0          1
# 4767      0     0          1
# 4768      0     0          1
# 4769      0     0          1
# 4770      0     0          1
#
# [940 rows x 15 columns]

# %%
Warren['Politician']='Warren'
Bernie['Politician']='Bernie'
Biden['Politician']='Biden'
Pete['Politician']='Pete'
Bloomberg['Politician']='Bloomberg'

# %%
Candidates=Warren.append(Bernie)
Candidates=Candidates.append(Biden)
Candidates=Candidates.append(Pete)
Candidates=Candidates.append(Bloomberg)

# %%
Candidates['Politician'].value_counts()
# Out:
# Bernie       940
# Warren       603
# Bloomberg    525
# Biden        472
# Pete         438
# Name: Politician, dtype: int64

# %%
drop=['user', 'Politician']
Candidates=Candidates.drop_duplicates(subset=drop)

# %%
Candidates
# Out:
#       Unnamed: 0             user                    location  \
# 1              1     LeftSideKrew  The Beltway Washington, DC
# 1437         463         patte151                 Lansing, MI
# 1941         967      patrickcurl                   Provo, UT
# 2536         616   BANNEDdotVIDEO                         NaN
# 2932          16   WestJournalism                 Phoenix, AZ
# ...          ...              ...                         ...
# 4766         994           jdar57                         NaN
# 4767         995  Tommy_Blackjack                         NaN
# 4768         996     ButlerRunner                 Phoenix, AZ
# 4769         997      gilldaniels                      Boston
# 4770         998          mrcrom1                         NaN
#
#                                                   tweet           created_at  \
# 1      on bloomberg 'already right wing racist misog...  2020-02-19 22:25:39
# 1437   #joebiden #elizabethwarren #amyklobuchar and ...  2020-02-19 19:15:15
# 1941   please share and retweet let's get 1 million ...  2020-02-19 14:01:03
# 2536   #mikebloomberg loves you!🔥 __________________...  2020-02-19 18:20:33
# 2932   candidates took veiled shots as zimmerman whi...  2020-02-19 22:30:32
# ...                                                 ...                  ...
# 4766   why no one should sell #elizabethwarren short...  2020-02-19 14:59:32
# 4767   why no one should sell #elizabethwarren short...  2020-02-19 14:58:48
# 4768   why no one should sell #elizabethwarren short...  2020-02-19 14:58:46
# 4769   why no one should sell #elizabethwarren short...  2020-02-19 14:58:00
# 4770   why no one should sell #elizabethwarren short...  2020-02-19 14:57:35
#
#      original_creator  retweet  degrees  value  \
# 1        LeftSideKrew        0        1      2
# 1437         patte151        0        1      2
# 1941      patrickcurl        0        1      2
# 2536   BANNEDdotVIDEO        0        1      2
# 2932   WestJournalism        0        1      2
# ...               ...      ...      ...    ...
# 4766        mayawiley        1        1      5
# 4767        mayawiley        1        1      5
# 4768        mayawiley        1        1      5
# 4769        mayawiley        1        1      5
# 4770        mayawiley        1        1      5
#
#                                                 hashtag  Warren  Bernie  \
# 1     ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 1437  ['#joebiden', '#elizabethwarren', '#amyklobuch...       1       0
# 1941  ['#bernieorbusters', '#bernieorbust', '#bernie...       1       1
# 2536                   ['#mikebloomberg', '#infowars:']       1       1
# 2932  ["#trayvonmartin's", '#2020election', '#elizab...       1       0
# ...                                                 ...     ...     ...
# 4766          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4767          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4768          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4769          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4770          ['#elizabethwarren', '#michaelbloomberg']       1       1
#
#       Biden  Pete  Bloomberg Politician  value_candidate
# 1         1     1          1     Warren             1.00
# 1437      1     0          0     Warren             1.00
# 1941      1     1          0     Warren             1.00
# 2536      0     0          1     Warren             1.00
# 2932      0     1          0     Warren             1.00
# ...     ...   ...        ...        ...              ...
# 4766      0     0          1  Bloomberg             0.75
# 4767      0     0          1  Bloomberg             0.75
# 4768      0     0          1  Bloomberg             0.75
# 4769      0     0          1  Bloomberg             0.75
# 4770      0     0          1  Bloomberg             0.75
#
# [2455 rows x 17 columns]

# %%
import networkx as nx
# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    Candidates,
    target = 'Politician',
    source = 'user', 
    create_using = nx.DiGraph())

# %%
print('Nodes in RT network:', len(network.nodes()))
print('Edges in RT network:', len(network.edges()))
# Out:
# Nodes in RT network: 1701
# Edges in RT network: 2455

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx


def assign_candidate(Politician): 

    if 'Bernie'in Politician: 
        return 1
    if 'Biden'in Politician: 
        return 4
    if 'Bloomberg'in Politician: 
        return 5
    if 'Pete'in Politician: 
        return 3
    if 'Warren' in Politician: 
        return 2
    return 0.0

Candidates['value'] = Candidates['Politician'].map(assign_candidate)
val_map = dict(zip(Candidates.user, Candidates.value))
values = [val_map.get(node, .25) for node in network.nodes()]

pos=nx.spring_layout(network)
val_map_values = {'BernieSanders': 1,'ElizabethWarren': 2,'PeteButtigieg': 3,'JoeBiden': 4,'MikeBloomberg': 5}
# values = [val_map.get(node, 0) for node in network_politican.nodes()]
# Color mapping
jet = cm = plt.get_cmap('viridis')
cNorm  = colors.Normalize(vmin=0, vmax=max(values))
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

# Using a figure to use it as a parameter when calling nx.draw_networkx
f = plt.figure(1, figsize=(15, 15))
ax = f.add_subplot(1,1,1)
for label in val_map_values:
    ax.plot([0],[0],
            color=scalarMap.to_rgba(val_map_values[label]),
            label=label)

# Just fixed the color map
nx.draw_networkx(network,pos, cmap = jet, vmin=0, vmax= max(values),
                 node_color=values, 
                 with_labels=False,ax=ax)

# Here is were I get an error with your code                                                                                                                         
#nodes = nx.draw(G, cmap = plt.get_cmap('jet'), node_color = values)                                                                             

# Setting it to how it was looking before.                                                                                                              
plt.axis('off')
f.set_facecolor('w')

plt.legend(loc='best')


f.tight_layout()
plt.show()

# %%
#print(nx.is_connected(network))

# Next, use nx.connected_components to get the list of components,
# then use the max() command to find the largest one:
components = nx.connected_components(network)
largest_component = max(components, key=len)

# Create a "subgraph" of just the largest component
# Then calculate the diameter of the subgraph, just like you did with density.
#

subgraph = network.subgraph(largest_component)
diameter = nx.diameter(subgraph)
print("Network diameter of largest component:", diameter)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# <ipython-input-483-a83ce6f7b9e0> in <module>
#       3 # Next, use nx.connected_components to get the list of components,
#       4 # then use the max() command to find the largest one:
# ----> 5 components = nx.connected_components(network)
#       6 largest_component = max(components, key=len)
#       7
#
# </Users/vinaykhanijow/.conda/envs/mypython3/lib/python3.7/site-packages/decorator.py:decorator-gen-297> in connected_components(G)
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      78         if match:
#      79             msg = 'not implemented for %s type' % ' '.join(graph_types)
# ---> 80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
#      82             return not_implement_for_func(*args, **kwargs)
#
# NetworkXNotImplemented: not implemented for directed type

# %%
nx.info(network)

# %%
fell_whitehead_path = nx.shortest_path(network)

# %%
from multiprocessing import Pool
import itertools

# %%
def partitions(nodes, n):
    "Partitions the nodes into n subsets"
    nodes_iter = iter(nodes)
    while True:
        partition = tuple(itertools.islice(nodes_iter,n))
        if not partition:
            return
        yield partition

def btwn_pool(G_tuple):
    return nx.betweenness_centrality_source(*G_tuple)

def between_parallel(network, processes = None):
    p = Pool(processes=processes)
    part_generator = 4*len(p._pool)
    node_partitions = list(partitions(network.nodes(), int(len(network)/part_generator)))
    num_partitions = len(node_partitions)
 
    bet_map = p.map(btwn_pool,
                        zip([network]*num_partitions,
                        [True]*num_partitions,
                        [None]*num_partitions,
                        node_partitions))
 
    bt_c = bet_map[0]
    for bt in bet_map[1:]:
        for n in bt:
            bt_c[n] += bt[n]
    return bt_c

# %%
bt = between_parallel(network)
top = 10

max_nodes =  sorted(bt.items(), key = lambda v: -v[1])[:top]
bt_values = [5]*len(network.nodes())
bt_colors = [0]*len(network.nodes())
for max_key, max_val in max_nodes:
    bt_values[max_key] = 150
    bt_colors[max_key] = 2
 
plt.axis("off")
nx.draw_networkx(network, pos = spring_pos, cmap = plt.get_cmap("rainbow"), node_color = bt_colors, node_size = bt_values, with_labels = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-423-df5ac5d69d5c> in <module>
#       6 bt_colors = [0]*len(network.nodes())
#       7 for max_key, max_val in max_nodes:
# ----> 8     bt_values[max_key] = 150
#       9     bt_colors[max_key] = 2
#      10
#
# TypeError: list indices must be integers or slices, not str

# %%
def partitions(nodes, n):
    "Partitions the nodes into n subsets"
    nodes_iter = iter(nodes)
    while True:
        partition = tuple(itertools.islice(nodes_iter,n))
        if not partition:
            return
        yield partition
        
# To begin the parallel computation, we initialize a Pool object with the
# number of available processors on our hardware. We then partition the
# network based on the size of the Pool object (the size is equal to the 
# number of available processors). 
def between_parallel(network, processes = None):
    p = Pool(processes=processes)
    part_generator = 4*len(p._pool)
    node_partitions = list(partitions(network.nodes(), int(len(network)/part_generator)))
    num_partitions = len(node_partitions)
 
    #Next, we pass each processor a copy of the entire network and 
    #compute #the betweenness centrality for each vertex assigned to the 
    #processor.
 
    bet_map = p.map(btwn_pool,
                    zip([network]*num_partitions,
                        [True]*num_partitions,
                        [None]*num_partitions,
                        node_partitions))
 
    #Finally, we collect the betweenness centrality calculations from each 
    #pool and aggregate them together to compute the overall betweenness 
    #centrality score for each vertex in the network.
 
    bt_c = bet_map[0]
    for bt in bet_map[1:]:
        for n in bt:
            bt_c[n] += bt[n]
    return bt_c

# %%
graph_betweenness = nx.betweenness_centrality(network, normalized=True, endpoints=False)
sorted_bet=sorted(graph_betweenness.items(), key=lambda x: x[1], reverse=True)[:50]
sorted_bet
# Out:
# [('LeftSideKrew', 0.0),
#  ('patte151', 0.0),
#  ('patrickcurl', 0.0),
#  ('BANNEDdotVIDEO', 0.0),
#  ('WestJournalism', 0.0),
#  ('MHayehudi', 0.0),
#  ('TPInsidr', 0.0),
#  ('realgeorgelois', 0.0),
#  ('Carol64653456', 0.0),
#  ('RoniMinter', 0.0),
#  ('LadyRiverdale', 0.0),
#  ('Birl', 0.0),
#  ('GoodTwitty', 0.0),
#  ('thereseflanagan', 0.0),
#  ('ATHOMEActivism', 0.0),
#  ('Primal_Digest', 0.0),
#  ('Beckstle', 0.0),
#  ('WordsToVoteBy', 0.0),
#  ('TheBigDsEgo', 0.0),
#  ('SharonCarbine', 0.0),
#  ('somepplrk', 0.0),
#  ('SteveBrant', 0.0),
#  ('beachpelican', 0.0),
#  ('ene_liis', 0.0),
#  ('jo_jlsr3353', 0.0),
#  ('diannemando', 0.0),
#  ('iowamare', 0.0),
#  ('politstrip', 0.0),
#  ('steinhauserNH1', 0.0),
#  ('TheWashingtonRT', 0.0),
#  ('SPOTTEDDOG129', 0.0),
#  ('TeoMangialetti', 0.0),
#  ('Pinozoni', 0.0),
#  ('3blondes3', 0.0),
#  ('ericschellsays', 0.0),
#  ('nwayne66', 0.0),
#  ('NancyLeeGrahn', 0.0),
#  ('TinaDuryea', 0.0),
#  ('kristywoods', 0.0),
#  ('TeaWald', 0.0),
#  ('cfbronco', 0.0),
#  ('TribulationThe', 0.0),
#  ('smart_whit', 0.0),
#  ('GladiLDS', 0.0),
#  ('deb4elizabeth', 0.0),
#  ('1985_BTTF', 0.0),
#  ('AzPatriot88', 0.0),
#  ('bellaisola1', 0.0),
#  ('NancyBe74992119', 0.0),
#  ('alicia45KAG', 0.0)]

# %%
graph_closeness = nx.closeness_centrality(network)
sorted_closeness = sorted(graph_closeness.items(), key=lambda x: x[1], reverse=True)
DataFrame(sorted_closeness)[5:]
# Out:
#                     0         1
# 5          SallyDeal4  0.031124
# 6     youcantbeatpete  0.029971
# 7      benjaminwittes  0.027666
# 8             lindyli  0.019597
# 9       dragonian3333  0.017291
# ...               ...       ...
# 1731       DianaJ1973  0.000000
# 1732      zheinpathos  0.000000
# 1733  mikeford_bossie  0.000000
# 1734  christinehays15  0.000000
# 1735      LilacsxGirl  0.000000
#
# [1731 rows x 2 columns]

# %%
graph_centrality = nx.degree_centrality(network)
sorted_cent = sorted(graph_centrality.items(), key=lambda x: x[1], reverse=True)
DataFrame(sorted_cent)
# Out:
#                     0         1
# 0           mayawiley  0.097406
# 1       ResisterSis20  0.084726
# 2             Vozable  0.043228
# 3         FIGHT_2_KAG  0.037464
# 4       NancyLeeGrahn  0.032277
# ...               ...       ...
# 1731       DianaJ1973  0.000576
# 1732      zheinpathos  0.000576
# 1733  mikeford_bossie  0.000576
# 1734  christinehays15  0.000576
# 1735      LilacsxGirl  0.000576
#
# [1736 rows x 2 columns]

# %%
graph_centrality
# Out:
# {'LeftSideKrew': 0.0029411764705882353,
#  'Warren': 0.2788235294117647,
#  'patte151': 0.002352941176470588,
#  'patrickcurl': 0.0029411764705882353,
#  'BANNEDdotVIDEO': 0.001764705882352941,
#  'WestJournalism': 0.002352941176470588,
#  'MHayehudi': 0.001764705882352941,
#  'TPInsidr': 0.001176470588235294,
#  'realgeorgelois': 0.001764705882352941,
#  'Carol64653456': 0.000588235294117647,
#  'RoniMinter': 0.002352941176470588,
#  'LadyRiverdale': 0.001176470588235294,
#  'Birl': 0.000588235294117647,
#  'GoodTwitty': 0.000588235294117647,
#  'thereseflanagan': 0.000588235294117647,
#  'ATHOMEActivism': 0.001764705882352941,
#  'Primal_Digest': 0.001176470588235294,
#  'Beckstle': 0.001176470588235294,
#  'WordsToVoteBy': 0.000588235294117647,
#  'TheBigDsEgo': 0.002352941176470588,
#  'SharonCarbine': 0.002352941176470588,
#  'somepplrk': 0.001764705882352941,
#  'SteveBrant': 0.001176470588235294,
#  'beachpelican': 0.000588235294117647,
#  'ene_liis': 0.001764705882352941,
#  'jo_jlsr3353': 0.001764705882352941,
#  'diannemando': 0.000588235294117647,
#  'iowamare': 0.000588235294117647,
#  'politstrip': 0.000588235294117647,
#  'steinhauserNH1': 0.001764705882352941,
#  'TheWashingtonRT': 0.002352941176470588,
#  'SPOTTEDDOG129': 0.000588235294117647,
#  'TeoMangialetti': 0.001764705882352941,
#  'Pinozoni': 0.000588235294117647,
#  '3blondes3': 0.000588235294117647,
#  'ericschellsays': 0.001176470588235294,
#  'nwayne66': 0.001176470588235294,
#  'NancyLeeGrahn': 0.000588235294117647,
#  'TinaDuryea': 0.000588235294117647,
#  'kristywoods': 0.000588235294117647,
#  'cfbronco': 0.000588235294117647,
#  'TribulationThe': 0.001176470588235294,
#  'GladiLDS': 0.000588235294117647,
#  'deb4elizabeth': 0.002352941176470588,
#  '1985_BTTF': 0.001176470588235294,
#  'AzPatriot88': 0.001176470588235294,
#  'bellaisola1': 0.000588235294117647,
#  'NancyBe74992119': 0.001176470588235294,
#  'alicia45KAG': 0.002352941176470588,
#  'Tristanshouts': 0.000588235294117647,
#  'lachic288': 0.000588235294117647,
#  'LaurieSorensen7': 0.000588235294117647,
#  'Solutioneer72': 0.001176470588235294,
#  'jennytinch': 0.000588235294117647,
#  'Multijo1': 0.000588235294117647,
#  'PeopleMatter9': 0.000588235294117647,
#  'jessabahx': 0.000588235294117647,
#  'Addi_James': 0.000588235294117647,
#  'SheilaDecker19': 0.001176470588235294,
#  'BlueTexGal': 0.000588235294117647,
#  'Indi_Tx27': 0.000588235294117647,
#  'Gina4DJT2020': 0.001176470588235294,
#  'Maltomash': 0.000588235294117647,
#  'DelfinaValdez8': 0.000588235294117647,
#  'Brendajurgens3': 0.000588235294117647,
#  'SnarkedUpLawyer': 0.000588235294117647,
#  'carrilit': 0.001176470588235294,
#  'JeffSmith052965': 0.001764705882352941,
#  'SaveMyAmerica2': 0.001764705882352941,
#  'MesiaArte': 0.001176470588235294,
#  'irishzionist': 0.002352941176470588,
#  'GlennnRoss': 0.001176470588235294,
#  'sarasar09354574': 0.001176470588235294,
#  'ChewFor': 0.001176470588235294,
#  'LeeDAmato': 0.001176470588235294,
#  'ElderService': 0.001176470588235294,
#  'Laura78703': 0.001176470588235294,
#  'gramscista': 0.001176470588235294,
#  'marco_bal99': 0.001176470588235294,
#  'WebbRwebb8285': 0.001764705882352941,
#  'DFBbear': 0.001176470588235294,
#  'Melenis13': 0.001176470588235294,
#  'MichaelDadiego': 0.001176470588235294,
#  'Bukikki1': 0.001176470588235294,
#  'MillerCrime': 0.000588235294117647,
#  'teamster412': 0.000588235294117647,
#  'Womenpols': 0.001764705882352941,
#  'smithcaaron': 0.000588235294117647,
#  'davedwardspiano': 0.000588235294117647,
#  'FjsKika': 0.000588235294117647,
#  'CLManussier': 0.000588235294117647,
#  'devaney_robin': 0.000588235294117647,
#  'CrazyBob48': 0.000588235294117647,
#  'RosalieVermeire': 0.000588235294117647,
#  'juliawb': 0.000588235294117647,
#  'belladonnaflame': 0.000588235294117647,
#  'Speddoc': 0.000588235294117647,
#  'DebG415': 0.000588235294117647,
#  'SackmanBobbie': 0.000588235294117647,
#  'TNsmartgal': 0.000588235294117647,
#  'olyforwarren': 0.000588235294117647,
#  'thegodsarrive': 0.000588235294117647,
#  'WonderWoman412': 0.001764705882352941,
#  'rosietime': 0.000588235294117647,
#  'ClaraSilket': 0.000588235294117647,
#  'WarrenAlaska': 0.000588235294117647,
#  'flyovertruth': 0.000588235294117647,
#  'JB101_': 0.000588235294117647,
#  'KedTakeda': 0.000588235294117647,
#  'nycmsteacher': 0.001176470588235294,
#  'CathyOhrinGreip': 0.000588235294117647,
#  'carmen_sipotai': 0.000588235294117647,
#  'tahnoa_caleta': 0.000588235294117647,
#  'm2in84': 0.000588235294117647,
#  'tinahseattle': 0.000588235294117647,
#  'LauraHennesse11': 0.000588235294117647,
#  'hudsonhornet': 0.000588235294117647,
#  'Locou9': 0.000588235294117647,
#  'MelvinLee515': 0.000588235294117647,
#  'slowhands_kllr': 0.001764705882352941,
#  'playit7x': 0.000588235294117647,
#  'TomBenthin': 0.000588235294117647,
#  'jenn976': 0.000588235294117647,
#  'beerwxsports': 0.001764705882352941,
#  'witches_4warren': 0.001176470588235294,
#  'warren_wv': 0.000588235294117647,
#  'LarryHaddock': 0.000588235294117647,
#  'bright8694': 0.000588235294117647,
#  'Lolalammmers': 0.000588235294117647,
#  'mindycrary': 0.000588235294117647,
#  'fstockman': 0.000588235294117647,
#  'pswilliams': 0.000588235294117647,
#  'sity_cat': 0.000588235294117647,
#  'murielcooperI': 0.000588235294117647,
#  '_pbb18': 0.000588235294117647,
#  'elisabeth_pal': 0.001176470588235294,
#  'MkgilMary': 0.000588235294117647,
#  'LukesReceipts': 0.000588235294117647,
#  'apachegirl29': 0.000588235294117647,
#  'ConnieH90288807': 0.000588235294117647,
#  'MurphDugan': 0.001764705882352941,
#  'sba1211': 0.000588235294117647,
#  'CathyJoeGPT': 0.000588235294117647,
#  'MerPearlieMae': 0.000588235294117647,
#  'jeni_briere': 0.000588235294117647,
#  'anginthemiddle': 0.000588235294117647,
#  'mimimchugh7491': 0.000588235294117647,
#  'tomasrabago1': 0.000588235294117647,
#  'Ryn0ceros': 0.000588235294117647,
#  'Pennypark': 0.000588235294117647,
#  'barb_swan': 0.001764705882352941,
#  'treesandrivers': 0.000588235294117647,
#  'detroit_rachel': 0.000588235294117647,
#  's_w891': 0.001764705882352941,
#  'Free_Spirit2972': 0.000588235294117647,
#  'IwantJustice_17': 0.000588235294117647,
#  'lkbond': 0.000588235294117647,
#  'damnyankeeUP': 0.000588235294117647,
#  'LafizzyD': 0.001764705882352941,
#  'ValerieQuan': 0.000588235294117647,
#  'malshocker': 0.001764705882352941,
#  'MarionStrstrk': 0.000588235294117647,
#  'JeanNix7': 0.001764705882352941,
#  'ezrateach': 0.000588235294117647,
#  'TCLJocelyn': 0.000588235294117647,
#  'RogueLoonWoman7': 0.000588235294117647,
#  'Eden_Sarbanes': 0.000588235294117647,
#  'Azul_Sonya': 0.000588235294117647,
#  'cruzn101': 0.001764705882352941,
#  'SaftyInNumbers': 0.000588235294117647,
#  'MICHAELFBROOKS2': 0.000588235294117647,
#  'numb3r5ev3n': 0.000588235294117647,
#  'Suzette11779959': 0.000588235294117647,
#  'LeighMike87': 0.000588235294117647,
#  'JAMES_R_BRUNER': 0.000588235294117647,
#  'DemoFan24': 0.000588235294117647,
#  'DianeLois4': 0.001764705882352941,
#  'BigChief_MAGA': 0.000588235294117647,
#  'suehagadorn': 0.001764705882352941,
#  'mellie1951': 0.000588235294117647,
#  '5Xenophon5': 0.001764705882352941,
#  'montique47': 0.000588235294117647,
#  'JaneAddamsGhost': 0.000588235294117647,
#  'FloreyBarb': 0.000588235294117647,
#  'jocelyn_mcmahon': 0.001764705882352941,
#  'ChadwellToni': 0.000588235294117647,
#  'carolynsrealm': 0.001764705882352941,
#  'MHallmark11': 0.001764705882352941,
#  'TheRealRedRobyn': 0.000588235294117647,
#  'brandk110': 0.002352941176470588,
#  'PaulkateKelly': 0.000588235294117647,
#  'Uberficker': 0.000588235294117647,
#  'sbprophet': 0.001764705882352941,
#  'KeyonnaLashay': 0.000588235294117647,
#  'NohriGreta': 0.000588235294117647,
#  'thor2233': 0.000588235294117647,
#  'kristenarland': 0.000588235294117647,
#  'blcklvsmatut': 0.000588235294117647,
#  'aizuchi1': 0.000588235294117647,
#  'MissButter': 0.000588235294117647,
#  'lori2882': 0.000588235294117647,
#  'poodlepingpong': 0.000588235294117647,
#  'bigdaddybiglove': 0.000588235294117647,
#  'obinson': 0.000588235294117647,
#  'BeardWrites': 0.000588235294117647,
#  'trinigyaaaal': 0.000588235294117647,
#  'OnEdge17': 0.000588235294117647,
#  'johnjspano': 0.000588235294117647,
#  'XxJeminyeXIII': 0.000588235294117647,
#  'rtd03': 0.000588235294117647,
#  'BlueSkyDays17': 0.000588235294117647,
#  'DonaldSmith8': 0.000588235294117647,
#  'sundene': 0.000588235294117647,
#  'JamaicanScholar': 0.000588235294117647,
#  'BushinskiSusan': 0.001764705882352941,
#  'WeezyStayLive15': 0.000588235294117647,
#  'kblood': 0.000588235294117647,
#  'FredTJoseph': 0.000588235294117647,
#  'pvdork': 0.000588235294117647,
#  'Liz960': 0.000588235294117647,
#  'BigOlPuma': 0.000588235294117647,
#  'henke_brooke': 0.001764705882352941,
#  'LouiseLayton4': 0.001764705882352941,
#  'kimberley_yurk': 0.001764705882352941,
#  'LovemySancho': 0.000588235294117647,
#  'JimWurst1': 0.000588235294117647,
#  'Kristie58407111': 0.001764705882352941,
#  'LTrutter': 0.000588235294117647,
#  'tallies53': 0.000588235294117647,
#  'schott_marty': 0.001764705882352941,
#  'hart35846751': 0.000588235294117647,
#  'TheAwkwardGOP': 0.000588235294117647,
#  'youcnbmywingman': 0.000588235294117647,
#  'SpyDoggie': 0.001764705882352941,
#  'CourtRetort': 0.000588235294117647,
#  'phidippides26': 0.000588235294117647,
#  'ShoutAloudNow': 0.000588235294117647,
#  'lisastran': 0.000588235294117647,
#  'gaelicartguy': 0.001764705882352941,
#  'corennacornwell': 0.000588235294117647,
#  'JenDegtjarewsky': 0.001764705882352941,
#  'PMaker27': 0.001764705882352941,
#  'politeperson123': 0.001764705882352941,
#  'UXB111': 0.001176470588235294,
#  'factsonlyplse': 0.001764705882352941,
#  'marylispastit': 0.000588235294117647,
#  'BronzeStarVet': 0.000588235294117647,
#  'MerlinGyr': 0.000588235294117647,
#  'melissasvoice': 0.000588235294117647,
#  'MAK7591': 0.001764705882352941,
#  'phillyforwarren': 0.000588235294117647,
#  'LizBecker55': 0.001764705882352941,
#  'tel_lucido': 0.001764705882352941,
#  'Penny_G': 0.001764705882352941,
#  'EllenCotler': 0.001764705882352941,
#  'wismiss3': 0.000588235294117647,
#  'ChristineGitte6': 0.001764705882352941,
#  'Ruth_elsesser': 0.000588235294117647,
#  'kimberlydawnb': 0.000588235294117647,
#  'ArtisanPastry': 0.000588235294117647,
#  'muadglib': 0.000588235294117647,
#  'colortheheart': 0.000588235294117647,
#  'CoolerK14': 0.001764705882352941,
#  'Shannon96011206': 0.001764705882352941,
#  'homegypsy': 0.002352941176470588,
#  'Aceysmommy04': 0.000588235294117647,
#  'BillieO2': 0.001764705882352941,
#  'rockyspike': 0.000588235294117647,
#  'SDscribbler': 0.001764705882352941,
#  'Mdart15': 0.000588235294117647,
#  'TracyBaron2': 0.001764705882352941,
#  'martaclau': 0.000588235294117647,
#  'rosecarmethine': 0.001764705882352941,
#  'MCEA1969': 0.000588235294117647,
#  'khillian13': 0.001176470588235294,
#  'LuczakVivien': 0.000588235294117647,
#  'trudyt': 0.001764705882352941,
#  'ebrulz': 0.001764705882352941,
#  'rbgismyog': 0.000588235294117647,
#  'MJFrancis7': 0.000588235294117647,
#  'goonertim1': 0.001764705882352941,
#  'ESchminkey': 0.000588235294117647,
#  'supra6red': 0.001764705882352941,
#  'amidthetumult': 0.001764705882352941,
#  'enough_2016': 0.000588235294117647,
#  'MaryWerblin': 0.001764705882352941,
#  'CanuckCognizant': 0.001764705882352941,
#  'SoCallls': 0.001764705882352941,
#  'ElliFtaka': 0.001764705882352941,
#  'psychofoundme': 0.001764705882352941,
#  'jmp1133': 0.001764705882352941,
#  'wickedlysteph': 0.000588235294117647,
#  'Aurora_Radagast': 0.001764705882352941,
#  'jackhutton': 0.001764705882352941,
#  'Popcornbytes': 0.000588235294117647,
#  'philipsgma': 0.000588235294117647,
#  'jhosker01': 0.001764705882352941,
#  'JasonOverstreet': 0.001764705882352941,
#  'mindfulone1500': 0.000588235294117647,
#  'XandryNicole': 0.001764705882352941,
#  'WendyD86': 0.001764705882352941,
#  'CallingAstro424': 0.001764705882352941,
#  'OtherKathy': 0.000588235294117647,
#  'DaveDekker8': 0.001764705882352941,
#  'rancho_steve': 0.000588235294117647,
#  'vivartist14': 0.000588235294117647,
#  'dylanhenning': 0.000588235294117647,
#  'ditzyblonde1354': 0.000588235294117647,
#  'msusysullivan': 0.000588235294117647,
#  'mahon595': 0.000588235294117647,
#  'Evpseattle': 0.001764705882352941,
#  'zebrezee': 0.000588235294117647,
#  'LeftyBotty': 0.000588235294117647,
#  'moonbreeze2': 0.001764705882352941,
#  'LauraMcAfee1': 0.000588235294117647,
#  'MaryAnneGruen': 0.001764705882352941,
#  'truthglow': 0.000588235294117647,
#  'vegan1818': 0.000588235294117647,
#  'mikeystep': 0.000588235294117647,
#  'gypsy31811': 0.001764705882352941,
#  'aviente': 0.001764705882352941,
#  'Christi12319172': 0.000588235294117647,
#  'eatweepandsleep': 0.001764705882352941,
#  'StDruther': 0.000588235294117647,
#  'pmnurse007': 0.001764705882352941,
#  'iamjennleal': 0.001764705882352941,
#  'blondie36621': 0.001764705882352941,
#  'dawnethorne': 0.002352941176470588,
#  'ZenPopArt': 0.001764705882352941,
#  'AzraelPC': 0.001764705882352941,
#  'cheryl_marlin': 0.001764705882352941,
#  'KellyAy34241143': 0.001764705882352941,
#  'ballerinaX': 0.001764705882352941,
#  'Lawgirl318': 0.001764705882352941,
#  'sajidshahriar': 0.001764705882352941,
#  'Arimenthe': 0.001764705882352941,
#  'wwing1234': 0.001764705882352941,
#  'adamcbest': 0.001764705882352941,
#  'SilvijaKrebs': 0.001764705882352941,
#  'LustigSandi': 0.001764705882352941,
#  'petitethirty1': 0.000588235294117647,
#  'nocatweet': 0.001764705882352941,
#  'LoveNotHateDFW': 0.000588235294117647,
#  'happyshinyrobin': 0.000588235294117647,
#  'Lori28052425': 0.000588235294117647,
#  'BeckyIB': 0.001764705882352941,
#  'suestoy95': 0.000588235294117647,
#  'Battleriverbab1': 0.000588235294117647,
#  'snatrone': 0.000588235294117647,
#  'downingmatt6': 0.000588235294117647,
#  'BirdsongSonja': 0.000588235294117647,
#  'lilfonts': 0.000588235294117647,
#  'ZackSTaylor1': 0.000588235294117647,
#  'marticates': 0.000588235294117647,
#  'DaveensMoore': 0.000588235294117647,
#  'JazzListening': 0.001764705882352941,
#  'enlightenment64': 0.001764705882352941,
#  'truBrooklynite': 0.001764705882352941,
#  'Imfrommichigan': 0.000588235294117647,
#  'bluejayseh': 0.000588235294117647,
#  'agavecorn': 0.001764705882352941,
#  'ruizzz4': 0.000588235294117647,
#  'TiffanyCadenhe1': 0.001764705882352941,
#  'socalmd54': 0.000588235294117647,
#  'rebecca_philly': 0.000588235294117647,
#  'NotoriousVOG': 0.000588235294117647,
#  'Lydia91436965': 0.001764705882352941,
#  'UOforWarren': 0.000588235294117647,
#  'court_wing': 0.001764705882352941,
#  'josurvivor': 0.000588235294117647,
#  'Mama2Pissed': 0.001764705882352941,
#  'LNightingale33': 0.000588235294117647,
#  'diahannlassus': 0.001764705882352941,
#  'dwdorsey01': 0.000588235294117647,
#  'bymarsam': 0.000588235294117647,
#  'plrbrs': 0.000588235294117647,
#  'Ummismaelsf': 0.000588235294117647,
#  'HotalingDB': 0.000588235294117647,
#  'enidlogan': 0.001764705882352941,
#  'carol_clovely4': 0.000588235294117647,
#  'gma4resistance': 0.001764705882352941,
#  'clo_leone': 0.000588235294117647,
#  'mgmendacious': 0.000588235294117647,
#  'delantz': 0.001764705882352941,
#  'linda_mallery': 0.000588235294117647,
#  'romansyear2020': 0.000588235294117647,
#  'jimenapiacumbe': 0.001764705882352941,
#  'LadyRaven3': 0.000588235294117647,
#  'BarbBanfieldRN': 0.001764705882352941,
#  'RokinRobin': 0.000588235294117647,
#  'avoidchaos': 0.000588235294117647,
#  'humanssuck12': 0.001764705882352941,
#  'Kaye9Nikki': 0.001764705882352941,
#  'SandyPideritPhD': 0.000588235294117647,
#  'LuluLovesTy': 0.000588235294117647,
#  'WriterChickNJ': 0.000588235294117647,
#  'InchieLada': 0.001764705882352941,
#  'FebWriter': 0.000588235294117647,
#  'StacyDolsen': 0.001764705882352941,
#  'rcschmeling': 0.001764705882352941,
#  'Aim2bme23': 0.000588235294117647,
#  'hjuleehebert': 0.000588235294117647,
#  'Laurenm57': 0.000588235294117647,
#  'SeidmanLea': 0.000588235294117647,
#  'RebeccaResistor': 0.000588235294117647,
#  'Kaore': 0.000588235294117647,
#  'Framedsgncr': 0.001764705882352941,
#  'fitzy532': 0.001764705882352941,
#  'jpen98': 0.001764705882352941,
#  'jeffsroses': 0.000588235294117647,
#  'CowgirlGramms': 0.000588235294117647,
#  'KathCLeSage': 0.001764705882352941,
#  'namaste90111': 0.001764705882352941,
#  'Detroit_Redhead': 0.000588235294117647,
#  'LindaCollins11': 0.000588235294117647,
#  'blakerspalding': 0.000588235294117647,
#  'Lyn_Zim': 0.001764705882352941,
#  'doolittlelady': 0.001764705882352941,
#  'Sailnjg': 0.000588235294117647,
#  'cd2action': 0.001764705882352941,
#  'JewelFrick': 0.001764705882352941,
#  'KathyDHz': 0.000588235294117647,
#  'SoCalforWarren': 0.000588235294117647,
#  'LizRodr42': 0.001764705882352941,
#  '_bitter_root': 0.001764705882352941,
#  'nyc4warren': 0.000588235294117647,
#  'IGLV_05': 0.001764705882352941,
#  'anddontgiveup': 0.001764705882352941,
#  'cheezwitham': 0.000588235294117647,
#  'NellieBlithe': 0.000588235294117647,
#  'SamKeaton4': 0.000588235294117647,
#  'DrlocksLocks': 0.000588235294117647,
#  'bechey': 0.001764705882352941,
#  'lindadoherty4': 0.001764705882352941,
#  'pwtrack': 0.001764705882352941,
#  'KBrancolini': 0.001764705882352941,
#  'CLLardner': 0.001764705882352941,
#  'Wingsfixed2FlyO': 0.001764705882352941,
#  'StarrReporters': 0.001764705882352941,
#  'abbimireille': 0.001764705882352941,
#  'WrenSoar': 0.001764705882352941,
#  'TalkinToU': 0.001764705882352941,
#  'GalloMarcia': 0.000588235294117647,
#  'brigidmodonnell': 0.001764705882352941,
#  'JenEvans6544': 0.001764705882352941,
#  'liz_allder': 0.001764705882352941,
#  'AWrobley': 0.001764705882352941,
#  'pamelafender': 0.000588235294117647,
#  'dolliod': 0.001764705882352941,
#  'LeaWmsVO': 0.001764705882352941,
#  'Quarternote2539': 0.001764705882352941,
#  'TYNEBSH': 0.000588235294117647,
#  'Restless1125': 0.001764705882352941,
#  'marshams3': 0.001764705882352941,
#  'disharpe1': 0.000588235294117647,
#  'GPhiker': 0.001764705882352941,
#  'Curious1Too': 0.001764705882352941,
#  'SylviaZ1913': 0.001764705882352941,
#  'damian_godden': 0.001764705882352941,
#  'stars_kaleid': 0.000588235294117647,
#  'lewing99': 0.001764705882352941,
#  'mhart45': 0.001764705882352941,
#  'helyn4': 0.001764705882352941,
#  'dietotaku': 0.000588235294117647,
#  'margare32075582': 0.001764705882352941,
#  'MsPiggy02': 0.001764705882352941,
#  'LilyofBiscay': 0.001764705882352941,
#  'dmjossel': 0.000588235294117647,
#  'TouchtonGina': 0.001764705882352941,
#  'jdar57': 0.001764705882352941,
#  'Tommy_Blackjack': 0.001764705882352941,
#  'ButlerRunner': 0.001764705882352941,
#  'gilldaniels': 0.001764705882352941,
#  'mrcrom1': 0.001764705882352941,
#  'gilajoanne': 0.000588235294117647,
#  'Bernie': 0.46705882352941175,
#  'FIGHT_2_KAG': 0.000588235294117647,
#  'NerdyHappy': 0.000588235294117647,
#  'turn_vote': 0.001764705882352941,
#  'priyadxe27': 0.000588235294117647,
#  'IDIOTdella': 0.000588235294117647,
#  'oyebee': 0.001176470588235294,
#  'TrumpKingofthe1': 0.001764705882352941,
#  'MimiTexasAngel': 0.001764705882352941,
#  'Meghan_BB_': 0.001764705882352941,
#  'RedRedGreen': 0.001176470588235294,
#  'gangstermiles': 0.001176470588235294,
#  'KristineCummins': 0.000588235294117647,
#  'CyrusShares': 0.000588235294117647,
#  'Jamie_Margolin': 0.000588235294117647,
#  'judymorris3': 0.000588235294117647,
#  'AmyCMcintosh': 0.001176470588235294,
#  'WhartonDj': 0.000588235294117647,
#  'mobygrapefan': 0.000588235294117647,
#  'LostDiva': 0.000588235294117647,
#  'AdreanaInLB': 0.000588235294117647,
#  'KENNYBOO93': 0.001764705882352941,
#  'CorporatePiggie': 0.001764705882352941,
#  'EricJafMN': 0.001176470588235294,
#  'MaQualeSantone': 0.001176470588235294,
#  'ForIAmKing78': 0.001764705882352941,
#  'JamesMArcher': 0.002352941176470588,
#  'iloanya1': 0.001764705882352941,
#  'kpnationalist19': 0.002352941176470588,
#  'markfinkelstein': 0.001176470588235294,
#  'CliffAYoung': 0.001764705882352941,
#  'Dootster': 0.001176470588235294,
#  'UpNorth62': 0.001176470588235294,
#  'POCForWarren': 0.001176470588235294,
#  'lilo623': 0.001176470588235294,
#  'mikewarder1': 0.001176470588235294,
#  'Dissensual': 0.001176470588235294,
#  'derekdob': 0.001764705882352941,
#  'byphilcrawford': 0.001764705882352941,
#  'SovernNation': 0.001176470588235294,
#  'jphoganorg': 0.001764705882352941,
#  'CotoBlogzz': 0.001176470588235294,
#  'LRBitisnot': 0.001176470588235294,
#  'PellaLibertas': 0.001176470588235294,
#  'Twitlertwit': 0.001176470588235294,
#  'blenhoff1': 0.001176470588235294,
#  'AmericansUnit': 0.001176470588235294,
#  'VetrepreneurOne': 0.001764705882352941,
#  'tararosenblum': 0.001176470588235294,
#  'Rebeccarivas': 0.001176470588235294,
#  'trekkerteach12': 0.001764705882352941,
#  'Aggies4T': 0.001176470588235294,
#  'KitOConnell': 0.001176470588235294,
#  'BHVT': 0.001176470588235294,
#  'TobiasSKC': 0.002352941176470588,
#  'benjaminwittes': 0.000588235294117647,
#  'apadillafilm6': 0.001176470588235294,
#  'ScottHolleran': 0.001176470588235294,
#  'AdrianaCohen16': 0.001176470588235294,
#  'WRPitt': 0.001176470588235294,
#  'RzstProgramming': 0.001176470588235294,
#  'ImpeachaBall': 0.001176470588235294,
#  'TeamKAG2020': 0.000588235294117647,
#  'TheLeftIsComing': 0.001176470588235294,
#  'JenniferCobra': 0.000588235294117647,
#  'baalter': 0.000588235294117647,
#  'nick75202282': 0.000588235294117647,
#  'Iam_AtifHafeez': 0.000588235294117647,
#  'cruzn4me03': 0.000588235294117647,
#  'teriyo': 0.000588235294117647,
#  'meow2438': 0.001176470588235294,
#  'OP_Omom': 0.001176470588235294,
#  'castello2': 0.000588235294117647,
#  'BrenOlver': 0.000588235294117647,
#  'lopez42706768': 0.000588235294117647,
#  'jufconnie': 0.000588235294117647,
#  'lacymeoww': 0.000588235294117647,
#  'vegan_pa': 0.000588235294117647,
#  'QHouser': 0.000588235294117647,
#  'miaculpepper2': 0.000588235294117647,
#  'DeniseEllenburg': 0.000588235294117647,
#  'qapitalistt': 0.000588235294117647,
#  'DennisAldea': 0.000588235294117647,
#  'LUSKER29': 0.000588235294117647,
#  'JoshuaKogut': 0.000588235294117647,
#  'Formal_Andy': 0.000588235294117647,
#  'TrumpsGAGirl': 0.000588235294117647,
#  'KellyStreeper': 0.000588235294117647,
#  'fredworld682': 0.000588235294117647,
#  'akuma_river': 0.001176470588235294,
#  'theleftyleftie': 0.000588235294117647,
#  'DxEMiami': 0.000588235294117647,
#  'Jaimeesue': 0.000588235294117647,
#  'KarmaSQuirr3l17': 0.001176470588235294,
#  'zephycat229': 0.000588235294117647,
#  'AlissaVierra': 0.000588235294117647,
#  'JustaDumguy': 0.000588235294117647,
#  'HoracioJDelgad1': 0.000588235294117647,
#  'ChloeLeffakis': 0.000588235294117647,
#  'agabus98': 0.000588235294117647,
#  'Jakezirk': 0.000588235294117647,
#  'DxEPittsburgh': 0.000588235294117647,
#  'anita_bl8': 0.001176470588235294,
#  'Cuneoborn': 0.000588235294117647,
#  'Phyllis58839295': 0.000588235294117647,
#  'Coffeee_Break': 0.000588235294117647,
#  'HeartBerns': 0.000588235294117647,
#  'GaryHauch': 0.000588235294117647,
#  'teresac16315456': 0.000588235294117647,
#  'farandaway6584': 0.000588235294117647,
#  'Sternl63': 0.000588235294117647,
#  'Manishmenna': 0.000588235294117647,
#  'DavidWilfand': 0.000588235294117647,
#  'Zadrina2': 0.000588235294117647,
#  'TexasKimberley': 0.000588235294117647,
#  'sxdoc': 0.000588235294117647,
#  'txdad': 0.000588235294117647,
#  'yplanes28': 0.000588235294117647,
#  'Kimbraov1': 0.001176470588235294,
#  'Jankowski60': 0.000588235294117647,
#  'tomdogftw': 0.000588235294117647,
#  'cleardawn88': 0.000588235294117647,
#  'NoDaTeddi': 0.000588235294117647,
#  'TetsuKaba': 0.001176470588235294,
#  'GaryJusseaume': 0.000588235294117647,
#  'aryservant': 0.000588235294117647,
#  'kaki58': 0.001176470588235294,
#  'TrumpSupport13': 0.000588235294117647,
#  'jsnswife332': 0.000588235294117647,
#  'chimchimgnzlz': 0.000588235294117647,
#  'Jayne_Martin': 0.000588235294117647,
#  'DMAMA232323': 0.000588235294117647,
#  'CapaTosta122': 0.001176470588235294,
#  'presadog': 0.000588235294117647,
#  'Bern4prez1': 0.001176470588235294,
#  'i314159265': 0.000588235294117647,
#  'holywell_john': 0.000588235294117647,
#  'petluvers4Trump': 0.000588235294117647,
#  '52Luchy': 0.000588235294117647,
#  'CCMustang17': 0.000588235294117647,
#  'Qrtrhrsryder': 0.000588235294117647,
#  'von1214': 0.000588235294117647,
#  'Ganymede0420': 0.000588235294117647,
#  'CatladyHanna': 0.000588235294117647,
#  'roberge_walter': 0.000588235294117647,
#  'StunnerSYoung': 0.000588235294117647,
#  'jlpowellp': 0.000588235294117647,
#  'diamactive2001': 0.000588235294117647,
#  'JouMoore': 0.000588235294117647,
#  'Christo29932651': 0.000588235294117647,
#  'nmickeyblue': 0.000588235294117647,
#  'lease903': 0.000588235294117647,
#  'leilacleigh': 0.000588235294117647,
#  'ROOFER711UNION': 0.000588235294117647,
#  'bernieshq': 0.001176470588235294,
#  'AtomicElbow': 0.000588235294117647,
#  'Pterrynosaurus': 0.000588235294117647,
#  'SassyG8tor': 0.000588235294117647,
#  'vibing_exe': 0.000588235294117647,
#  'marceyplay': 0.000588235294117647,
#  'ZionMTH': 0.001176470588235294,
#  'signifyify': 0.001176470588235294,
#  'VUnqualified': 0.000588235294117647,
#  'sorensen_ghost': 0.000588235294117647,
#  'DaveEsporado': 0.000588235294117647,
#  'dudelove88': 0.001176470588235294,
#  'beautyhero1': 0.000588235294117647,
#  'CSFuqua': 0.001176470588235294,
#  'mc_silva57': 0.000588235294117647,
#  'napardis': 0.000588235294117647,
#  'ChaunceySprague': 0.000588235294117647,
#  'charlesapker': 0.000588235294117647,
#  'TheBernReport': 0.000588235294117647,
#  'Parthenon1': 0.000588235294117647,
#  'berniebabee': 0.000588235294117647,
#  'tinatrout': 0.000588235294117647,
#  'PaulTasker14': 0.000588235294117647,
#  'WompWompWAWA': 0.000588235294117647,
#  'Tav_assoli': 0.000588235294117647,
#  'leelat143': 0.000588235294117647,
#  'afandouangel': 0.000588235294117647,
#  'sinlimonysal': 0.000588235294117647,
#  'S4za4Lbrt': 0.000588235294117647,
#  'carmic14': 0.000588235294117647,
#  'animalonly': 0.000588235294117647,
#  'nahm315': 0.000588235294117647,
#  'NoelleWatson20': 0.000588235294117647,
#  'tscott1998': 0.001176470588235294,
#  'linda_lindylou': 0.001176470588235294,
#  'FallerLawrence': 0.000588235294117647,
#  'lora_rinehart': 0.000588235294117647,
#  'Capitalijioso': 0.000588235294117647,
#  'ecbackee': 0.000588235294117647,
#  'jtoolr': 0.000588235294117647,
#  'Sammyboy1216': 0.000588235294117647,
#  'brandongmz7': 0.000588235294117647,
#  'ACleverNickname': 0.000588235294117647,
#  'Georgiemutt': 0.000588235294117647,
#  'TLMArmstrong': 0.000588235294117647,
#  'KandorKarteh': 0.000588235294117647,
#  'David_DScalett': 0.000588235294117647,
#  'JoJoVegasBaby': 0.000588235294117647,
#  'Ashis34332869': 0.000588235294117647,
#  'peaceluvbernie': 0.000588235294117647,
#  'CJCordier': 0.000588235294117647,
#  'TarynVaneWP101': 0.000588235294117647,
#  'BarbaraLNewsome': 0.000588235294117647,
#  'vansopinion8ted': 0.000588235294117647,
#  'ShriverBob': 0.000588235294117647,
#  'MichGall702': 0.000588235294117647,
#  'StupidBastid': 0.000588235294117647,
#  '_FoggyDew': 0.000588235294117647,
#  'RandiLittle20': 0.000588235294117647,
#  'twitnitrick': 0.000588235294117647,
#  'EmilyCohenB': 0.000588235294117647,
#  'trajan2448': 0.000588235294117647,
#  'scheel_lala': 0.001176470588235294,
#  'EclecticRadical': 0.000588235294117647,
#  'StandUp4USA_Pam': 0.000588235294117647,
#  'juliegd13': 0.000588235294117647,
#  'KenBerry611': 0.000588235294117647,
#  'StaceyQ1022': 0.000588235294117647,
#  'DanRadzikowski': 0.001176470588235294,
#  'GuilloryClaudia': 0.000588235294117647,
#  'Benito66123304': 0.000588235294117647,
#  'minnnyme': 0.001176470588235294,
#  'ElisaBern1': 0.000588235294117647,
#  'CarolMariani1': 0.000588235294117647,
#  'njacob5': 0.000588235294117647,
#  'india65219665': 0.000588235294117647,
#  'jennahjudd': 0.000588235294117647,
#  '13thethe': 0.000588235294117647,
#  'GaryC23619095': 0.001176470588235294,
#  'Jon_ThinksATYou': 0.000588235294117647,
#  'eloiseat6': 0.001176470588235294,
#  'fippyd': 0.000588235294117647,
#  'DonaldODaniels1': 0.000588235294117647,
#  '_________Johann': 0.000588235294117647,
#  'FC7HemiCuda': 0.000588235294117647,
#  'pattiarchi_usa': 0.000588235294117647,
#  'KenLingad': 0.000588235294117647,
#  'Kabila73': 0.000588235294117647,
#  'ASocialistKiwi': 0.000588235294117647,
#  'CalebJo62407414': 0.000588235294117647,
#  'RicardoRiveraNJ': 0.000588235294117647,
#  'The_PingPing': 0.000588235294117647,
#  '650Beast': 0.000588235294117647,
#  'LiftyLefty': 0.000588235294117647,
#  'Abeyaftali': 0.000588235294117647,
#  'AlchemicalWheel': 0.000588235294117647,
#  'MARGIE352': 0.000588235294117647,
#  'LeftistKaiju': 0.000588235294117647,
#  'gchamp58': 0.000588235294117647,
#  'zmbywoof10': 0.000588235294117647,
#  'AKILOYUNU31': 0.000588235294117647,
#  'NYforSanders': 0.000588235294117647,
#  'SweetLadyUSA85': 0.000588235294117647,
#  'KateSanguinetti': 0.000588235294117647,
#  'jerZboyUSA': 0.000588235294117647,
#  'SKYRIDER4538': 0.000588235294117647,
#  'dogstar7tweets': 0.000588235294117647,
#  'SecOurRepublic': 0.000588235294117647,
#  'Socrates090': 0.000588235294117647,
#  '7Itsomar': 0.000588235294117647,
#  'ChiefCovfefe': 0.000588235294117647,
#  'Lady1776': 0.000588235294117647,
#  'Ivritagirl': 0.001176470588235294,
#  'MadelinePhilli1': 0.000588235294117647,
#  'HockeyFanGirl12': 0.000588235294117647,
#  'AmazingBernie': 0.000588235294117647,
#  'eynelys': 0.000588235294117647,
#  'fondaconley14': 0.000588235294117647,
#  'thatmags': 0.000588235294117647,
#  'hajjehx2': 0.000588235294117647,
#  'hockeyprose': 0.000588235294117647,
#  'Selena_Adera': 0.001176470588235294,
#  'Mo__hini': 0.000588235294117647,
#  'poohsbrana': 0.000588235294117647,
#  'janestclair2': 0.001176470588235294,
#  'Tbaglady': 0.000588235294117647,
#  'SusanSoorenko': 0.001176470588235294,
#  'billm9': 0.000588235294117647,
#  'GotBeachGlass': 0.000588235294117647,
#  'LobassoMelanie': 0.000588235294117647,
#  'Wangenstein': 0.000588235294117647,
#  'quark18': 0.000588235294117647,
#  'StrackeKey': 0.001176470588235294,
#  'RizekImar': 0.000588235294117647,
#  '123andgo': 0.000588235294117647,
#  'mkulltra': 0.000588235294117647,
#  'RMpodol': 0.001176470588235294,
#  'PolitixAttack': 0.000588235294117647,
#  'k8tnix': 0.000588235294117647,
#  'KarenUniteWomen': 0.000588235294117647,
#  'DulyB1': 0.000588235294117647,
#  'Bam13706492': 0.000588235294117647,
#  'loosechicken99': 0.000588235294117647,
#  'GadflyPersia': 0.000588235294117647,
#  'gX4IK76J9YqkHEn': 0.000588235294117647,
#  'prepper1776': 0.000588235294117647,
#  'ForevaJoe': 0.001176470588235294,
#  'The_RealBigErn': 0.000588235294117647,
#  'Zachary03699160': 0.000588235294117647,
#  'rob_maceachern': 0.000588235294117647,
#  'AceTalks73': 0.000588235294117647,
#  'DrdaveAnddee': 0.000588235294117647,
#  'Begonia454': 0.000588235294117647,
#  'daguz80': 0.000588235294117647,
#  'fightBackAnon': 0.001176470588235294,
#  'swain241': 0.000588235294117647,
#  'MortySmithEsq': 0.000588235294117647,
#  'MKay54': 0.001176470588235294,
#  'leftyaaron': 0.000588235294117647,
#  'bjdrues': 0.000588235294117647,
#  'Wade_Turnbull': 0.000588235294117647,
#  'thetracymarks': 0.000588235294117647,
#  'LockhartJamest': 0.000588235294117647,
#  'groworpay': 0.000588235294117647,
#  'icstoopidppl': 0.000588235294117647,
#  'tudahl55': 0.000588235294117647,
#  'MonzterofHope': 0.000588235294117647,
#  'charliekaliroy': 0.000588235294117647,
#  'BernieSis1': 0.001176470588235294,
#  'ZuziKrause': 0.000588235294117647,
#  'misafrancoO': 0.000588235294117647,
#  'BirdieSeeders': 0.000588235294117647,
#  'march4progress': 0.001176470588235294,
#  'RachelLucca1': 0.001764705882352941,
#  'johncryan': 0.000588235294117647,
#  'larrycroc': 0.001176470588235294,
#  'KathyJoLloyd2': 0.001176470588235294,
#  'TRexUPSer1': 0.000588235294117647,
#  'Al_Maldives': 0.000588235294117647,
#  '_MJenk21': 0.000588235294117647,
#  'HugoSanBamBam': 0.000588235294117647,
#  'SFCHCP123': 0.000588235294117647,
#  'wolfgirl1': 0.000588235294117647,
#  'WindyDane': 0.000588235294117647,
#  'Sunshinette771': 0.000588235294117647,
#  'OurRevTexas': 0.000588235294117647,
#  'WeWillRiseOhio': 0.001176470588235294,
#  'CCorjulo': 0.001176470588235294,
#  'dalieat': 0.000588235294117647,
#  'BrewerJoni': 0.000588235294117647,
#  'PaulSorrentino3': 0.000588235294117647,
#  'Jscott1145': 0.000588235294117647,
#  'ValorOf1776': 0.000588235294117647,
#  'EaleyGregory': 0.000588235294117647,
#  'Conruthhoward': 0.000588235294117647,
#  'JodiKoberinski': 0.000588235294117647,
#  'parents4future': 0.000588235294117647,
#  'IreneKenneth3': 0.001176470588235294,
#  'Derpaler': 0.000588235294117647,
#  'ThePenExaminer': 0.000588235294117647,
#  'Angelign': 0.000588235294117647,
#  'ps9714': 0.001176470588235294,
#  'insportfoto': 0.000588235294117647,
#  'QcrushR': 0.000588235294117647,
#  'MountainRaptor': 0.001176470588235294,
#  'jsolorzanomd': 0.000588235294117647,
#  'cherylsnodgrass': 0.000588235294117647,
#  'Trudi21140637': 0.000588235294117647,
#  'ReginaRed4': 0.001176470588235294,
#  'PepperOceanna': 0.000588235294117647,
#  'Juan16756938': 0.000588235294117647,
#  'jamieluvsaj': 0.000588235294117647,
#  'AnimalLoversUn1': 0.000588235294117647,
#  'Itsmyopinion1': 0.000588235294117647,
#  'CausticBitchNC': 0.000588235294117647,
#  '4closureNation2': 0.000588235294117647,
#  'GrooveSDC': 0.000588235294117647,
#  'lilcheesestick': 0.000588235294117647,
#  'TaxNateSilver': 0.000588235294117647,
#  'ashestodust80': 0.000588235294117647,
#  'Elizabe11056007': 0.000588235294117647,
#  'itisfilthy': 0.000588235294117647,
#  'Here4Not': 0.001176470588235294,
#  'YesMommaS': 0.000588235294117647,
#  'baconisaspice': 0.000588235294117647,
#  'lexipher23': 0.000588235294117647,
#  'NotTheSydneyA': 0.001764705882352941,
#  'FTwist': 0.000588235294117647,
#  'LMarieB1978': 0.000588235294117647,
#  'TiredInOR4Now': 0.001176470588235294,
#  'LynnHolmes56': 0.000588235294117647,
#  'DouglasAlmon': 0.000588235294117647,
#  'howardbskrville': 0.000588235294117647,
#  'daniloaraujo87': 0.000588235294117647,
#  'bigmoneysucks': 0.000588235294117647,
#  'HayatAliAlpha': 0.000588235294117647,
#  '2GRIMREAPER3': 0.000588235294117647,
#  'SnipzPA': 0.000588235294117647,
#  'lisapease': 0.000588235294117647,
#  'jambie61': 0.000588235294117647,
#  'LudwigDavis': 0.000588235294117647,
#  'careaware': 0.000588235294117647,
#  'jeananncord': 0.000588235294117647,
#  'RB18': 0.000588235294117647,
#  'MiguelPPingo': 0.000588235294117647,
#  'AndyBGoodwin': 0.001176470588235294,
#  'lynette530': 0.000588235294117647,
#  'VT_Gemini': 0.000588235294117647,
#  'KenTimmerman': 0.000588235294117647,
#  'whatbriansays': 0.000588235294117647,
#  'nannieboo': 0.001176470588235294,
#  'joej2020usa': 0.000588235294117647,
#  'bsgirl2u': 0.000588235294117647,
#  'imagreenkat': 0.000588235294117647,
#  '_change_artist': 0.000588235294117647,
#  'betteronpage': 0.001764705882352941,
#  'Osaye1': 0.002352941176470588,
#  'ipsospabbate': 0.001176470588235294,
#  'Jax6655': 0.001764705882352941,
#  'FreeBeYouMe': 0.001764705882352941,
#  'lacadri34': 0.001764705882352941,
#  'keiranpedley': 0.001176470588235294,
#  'jcbjackson': 0.001176470588235294,
#  'kallebring1': 0.001176470588235294,
#  'Josemar97748092': 0.001176470588235294,
#  'ritaresarian': 0.001176470588235294,
#  'LivnWLupus': 0.001176470588235294,
#  'notsofastlane56': 0.001176470588235294,
#  'SteepJ24YT': 0.001176470588235294,
#  'Abigail29808882': 0.001764705882352941,
#  'AdrianWBourne': 0.001176470588235294,
#  'SamianMcB': 0.001176470588235294,
#  'Ricca_19': 0.001176470588235294,
#  'kaci1951': 0.001176470588235294,
#  'jrodr2001': 0.001764705882352941,
#  'MarkSharpton': 0.001176470588235294,
#  'dkmnow': 0.001176470588235294,
#  'Cressy777Jeri': 0.001176470588235294,
#  'RosieBud521': 0.001176470588235294,
#  'davwim': 0.001176470588235294,
#  'graydeadzombie': 0.001176470588235294,
#  'MuslimMissWorld': 0.001176470588235294,
#  'ckkirsch1': 0.001176470588235294,
#  'rmgg5553': 0.001176470588235294,
#  'Kabimbels71': 0.001176470588235294,
#  'evchrry': 0.001176470588235294,
#  'bam57581565': 0.001176470588235294,
#  'DFernandesSmith': 0.001176470588235294,
#  'PoloBelafonte': 0.001176470588235294,
#  'kr4zy8ts': 0.001176470588235294,
#  'dianerocks52': 0.001176470588235294,
#  'platanopr1ncess': 0.001176470588235294,
#  'EmmaNwOrie': 0.001176470588235294,
#  'bfraser747': 0.001176470588235294,
#  'thedailyangle': 0.001176470588235294,
#  'SunandSipCups': 0.001176470588235294,
#  'L3ft_3y3_': 0.001176470588235294,
#  'DatZeffeDoe': 0.001176470588235294,
#  'burnyhank': 0.001176470588235294,
#  'SherazKhanNYC': 0.001176470588235294,
#  'dabobbyg': 0.001176470588235294,
#  'HollyBlomberg': 0.001176470588235294,
#  'Kaesike': 0.001176470588235294,
#  'moniluv1': 0.001176470588235294,
#  'antoniodiasri': 0.001176470588235294,
#  'patsexie': 0.001764705882352941,
#  'StanWil64571915': 0.001176470588235294,
#  'jtressn10': 0.001176470588235294,
#  'atlandium': 0.001176470588235294,
#  'SJV2028': 0.001176470588235294,
#  'BaburRealer': 0.001176470588235294,
#  'DotDillon2': 0.001176470588235294,
#  'jimmied57': 0.001176470588235294,
#  'CorinnaBloom': 0.001176470588235294,
#  'MARINE_99ZULU': 0.001176470588235294,
#  'leila4bernie': 0.001176470588235294,
#  'alan_uplc': 0.001176470588235294,
#  'Paratroop4Trump': 0.001176470588235294,
#  'MoorchehD': 0.001176470588235294,
#  'Mu11784': 0.001176470588235294,
#  'Teacher92379034': 0.001176470588235294,
#  'PatrioticTLC': 0.001176470588235294,
#  'allaboutme4545': 0.001176470588235294,
#  'Raywoolford': 0.001176470588235294,
#  'PrinceInTheChi': 0.001176470588235294,
#  'nightshaderose': 0.001176470588235294,
#  'EcrnKath': 0.001176470588235294,
#  'FMAlchemist': 0.001176470588235294,
#  'reeseer1': 0.001176470588235294,
#  'aureliaglenn': 0.001176470588235294,
#  'GCHeHim1': 0.001176470588235294,
#  'allisonj2291': 0.001176470588235294,
#  'Canna2': 0.001176470588235294,
#  'AnitaWAnderson2': 0.001176470588235294,
#  'JeanRui2': 0.001176470588235294,
#  'dhillos318': 0.001176470588235294,
#  'Saminsunderland': 0.001176470588235294,
#  'startledsquirel': 0.001176470588235294,
#  'PMoor38884355': 0.001176470588235294,
#  'MarieForTrump1': 0.001176470588235294,
#  'JudyJudyinTexas': 0.001176470588235294,
#  'jillkessler': 0.001176470588235294,
#  'bap1757': 0.001176470588235294,
#  'ScottStrain6': 0.001176470588235294,
#  'madmatto66': 0.001176470588235294,
#  'KevinJ46522274': 0.001176470588235294,
#  'Amy30926502': 0.001176470588235294,
#  'xclude_sunny': 0.001176470588235294,
#  'Erikamt082015': 0.001176470588235294,
#  'JoMajority': 0.001176470588235294,
#  'kagusa88022': 0.001176470588235294,
#  'paulscotland5': 0.001176470588235294,
#  'DannySonOfJohn': 0.001176470588235294,
#  'republic_truth': 0.001176470588235294,
#  'nellydoc96': 0.001176470588235294,
#  'JCJ417': 0.001176470588235294,
#  'SarahEightEliza': 0.001176470588235294,
#  'm_brennan_edit': 0.001176470588235294,
#  'JudiBAILEY46': 0.001176470588235294,
#  'SteveSteveduke': 0.001176470588235294,
#  'Troy2k': 0.001176470588235294,
#  'kkdev1955': 0.001176470588235294,
#  'BradParker_': 0.001176470588235294,
#  'TimJoeC': 0.001176470588235294,
#  'CanonRobRhodes': 0.001176470588235294,
#  'NothingHoney_18': 0.001176470588235294,
#  'whitingviki': 0.001176470588235294,
#  'ReeetardNamer': 0.001176470588235294,
#  'MFHATER': 0.001176470588235294,
#  'letloverule42': 0.001176470588235294,
#  'DnDClericHorgar': 0.001176470588235294,
#  ...}

# %%
C_Bloomberg = Candidates[Candidates['Politician']=='Bloomberg']

# %%
C_Bloomberg
# Out:
#       Unnamed: 0             user                    location  \
# 1              1     LeftSideKrew  The Beltway Washington, DC
# 198          198        turn_vote                Mother Earth
# 348          348      TheBigDsEgo   #Trump's head, rent-free!
# 677          677  TrumpKingofthe1                         NaN
# 745          745      patrickcurl                   Provo, UT
# ...          ...              ...                         ...
# 4766         994           jdar57                         NaN
# 4767         995  Tommy_Blackjack                         NaN
# 4768         996     ButlerRunner                 Phoenix, AZ
# 4769         997      gilldaniels                      Boston
# 4770         998          mrcrom1                         NaN
#
#                                                   tweet           created_at  \
# 1      on bloomberg 'already right wing racist misog...  2020-02-19 22:25:39
# 198    now, but #berniesanders #coalition is expandi...  2020-02-19 22:04:00
# 348    little younger is looking better and better. ...  2020-02-19 21:29:43
# 677    @cnn whats left..they cant go after #berniesa...  2020-02-19 20:33:03
# 745    awesome... i hope it's effective! #bloombergt...  2020-02-19 20:19:22
# ...                                                 ...                  ...
# 4766   why no one should sell #elizabethwarren short...  2020-02-19 14:59:32
# 4767   why no one should sell #elizabethwarren short...  2020-02-19 14:58:48
# 4768   why no one should sell #elizabethwarren short...  2020-02-19 14:58:46
# 4769   why no one should sell #elizabethwarren short...  2020-02-19 14:58:00
# 4770   why no one should sell #elizabethwarren short...  2020-02-19 14:57:35
#
#      original_creator  retweet  degrees  value  \
# 1        LeftSideKrew        0        1      5
# 198         turn_vote        0        1      5
# 348       TheBigDsEgo        0        1      5
# 677   TrumpKingofthe1        0        1      5
# 745       patrickcurl        0        1      5
# ...               ...      ...      ...    ...
# 4766        mayawiley        1        1      5
# 4767        mayawiley        1        1      5
# 4768        mayawiley        1        1      5
# 4769        mayawiley        1        1      5
# 4770        mayawiley        1        1      5
#
#                                                 hashtag  Warren  Bernie  \
# 1     ['#bernie', '#berniesanders', '#bernie2020', '...       1       1
# 198   ['#berniesanders', '#coalition', '#bernie2020'...       0       1
# 348             ['#berniesanders', '#michaelbloomberg']       0       1
# 677         ['#berniesanders', '#bernie', '#bloomberg']       0       1
# 745   ['#bloombergtwostents', '#notmeus', '#neverblo...       0       1
# ...                                                 ...     ...     ...
# 4766          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4767          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4768          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4769          ['#elizabethwarren', '#michaelbloomberg']       1       1
# 4770          ['#elizabethwarren', '#michaelbloomberg']       1       1
#
#       Biden  Pete  Bloomberg Politician  value_candidate
# 1         1     1          1  Bloomberg             0.75
# 198       0     0          1  Bloomberg             0.75
# 348       0     0          1  Bloomberg             0.75
# 677       0     0          1  Bloomberg             0.75
# 745       1     0          1  Bloomberg             0.75
# ...     ...   ...        ...        ...              ...
# 4766      0     0          1  Bloomberg             0.75
# 4767      0     0          1  Bloomberg             0.75
# 4768      0     0          1  Bloomberg             0.75
# 4769      0     0          1  Bloomberg             0.75
# 4770      0     0          1  Bloomberg             0.75
#
# [440 rows x 17 columns]

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx

import networkx as nx
# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    C_Bloomberg,
    target = 'user',
    source = 'original_creator', 
    create_using = nx.DiGraph())
def assign_candidate(Politician): 

    if 'Bernie'in Politician: 
        return 1
    if 'Biden'in Politician: 
        return 4
    if 'Bloomberg'in Politician: 
        return 5
    if 'Pete'in Politician: 
        return 3
    if 'Warren' in Politician: 
        return 2
    return 0.0

C_Bloomberg['value'] = C_Bloomberg['Politician'].map(assign_candidate)
val_map = dict(zip(C_Bloomberg.user, C_Bloomberg.value))
values = [val_map.get(node, .25) for node in network.nodes()]

pos=nx.spring_layout(network)
val_map_values = {'BernieSanders': 1,'ElizabethWarren': 2,'PeteButtigieg': 3,'JoeBiden': 4,'MikeBloomberg': 5}
# values = [val_map.get(node, 0) for node in network_politican.nodes()]
# Color mapping
jet = cm = plt.get_cmap('viridis')
cNorm  = colors.Normalize(vmin=0, vmax=max(values))
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

# Using a figure to use it as a parameter when calling nx.draw_networkx
f = plt.figure(1, figsize=(15, 15))
ax = f.add_subplot(1,1,1)
for label in val_map_values:
    ax.plot([0],[0],
            color=scalarMap.to_rgba(val_map_values[label]),
            label=label)

# Just fixed the color map
nx.draw_networkx(network,pos, cmap = jet, vmin=0, vmax= max(values),
                 node_color=values, 
                 with_labels=False,ax=ax)

# Here is were I get an error with your code                                                                                                                         
#nodes = nx.draw(G, cmap = plt.get_cmap('jet'), node_color = values)                                                                             

# Setting it to how it was looking before.                                                                                                              
plt.axis('off')
f.set_facecolor('w')

plt.legend(loc='best')


f.tight_layout()
plt.show()

# %%
graph_centrality = nx.degree_centrality(network)
sorted_cent = sorted(graph_centrality.items(), key=lambda x: x[1], reverse=True)
DataFrame(sorted_cent)
# Out:
#                    0         1
# 0          mayawiley  0.336283
# 1     benjaminwittes  0.106195
# 2            JLPtalk  0.053097
# 3        KitOConnell  0.042035
# 4    RzstProgramming  0.030973
# ..               ...       ...
# 448           jdar57  0.002212
# 449  Tommy_Blackjack  0.002212
# 450     ButlerRunner  0.002212
# 451      gilldaniels  0.002212
# 452          mrcrom1  0.002212
#
# [453 rows x 2 columns]

# %%
graph_closeness = nx.closeness_centrality(network)
sorted_closeness = sorted(graph_closeness.items(), key=lambda x: x[1], reverse=True)
DataFrame(sorted_closeness)
# Out:
#                0         1
# 0       meow2438  0.002212
# 1    akuma_river  0.002212
# 2      anita_bl8  0.002212
# 3      TetsuKaba  0.002212
# 4         kaki58  0.002212
# ..           ...       ...
# 448  CaseStudyQB  0.000000
# 449   smart_whit  0.000000
# 450   DrMartyFox  0.000000
# 451  judymorris3  0.000000
# 452    mayawiley  0.000000
#
# [453 rows x 2 columns]

# %%
graph_betweenness = nx.betweenness_centrality(network, normalized=True, endpoints=False)
sorted_bet=sorted(graph_betweenness.items(), key=lambda x: x[1], reverse=True)[:50]
DataFrame(sorted_bet).head()
# Out:
#                  0    1
# 0     LeftSideKrew  0.0
# 1        turn_vote  0.0
# 2      TheBigDsEgo  0.0
# 3  TrumpKingofthe1  0.0
# 4      patrickcurl  0.0
