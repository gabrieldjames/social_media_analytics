# %%
import pandas as pd
from pandas import DataFrame, Series
import networkx as nx

import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

import matplotlib.pyplot as plt

# %%
biden = pd.read_csv('biden_total.csv')
bernie = pd.read_csv('feel_the_bern.csv')
trump = pd.read_csv('trumptweetdata_total.csv').dropna()
pete = pd.read_csv('PeteButtigieg.csv')
war = pd.read_csv('warren_combined_twitter.csv')
mike1 = pd.read_csv('bloomberg_Twitter_data.csv')
mike2 = pd.read_csv('bloomberg_Twitter_data2.csv')
mike3 = pd.read_csv('bloomberg_Twitter_data3.csv')
mike = mike1.append(mike2)
mike = mike.append(mike3).dropna()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bc206f2624a0> in <module>
# ----> 1 biden = pd.read_csv('biden_total.csv')
#       2 bernie = pd.read_csv('feel_the_bern.csv')
#       3 trump = pd.read_csv('trumptweetdata_total.csv').dropna()
#       4 pete = pd.read_csv('PeteButtigieg.csv')
#       5 war = pd.read_csv('warren_combined_twitter.csv')
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/.conda/envs/mypython3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'biden_total.csv' does not exist: b'biden_total.csv'

# %%
war.dropna()
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 3               3             3
# 6               6             6
# 7               7             7
# 9               9             9
# ...           ...           ...
# 29994        9994          9994
# 29995        9995          9995
# 29996        9996          9996
# 29997        9997          9997
# 29999        9999          9999
#
#                                             got_criteria         username  \
# 0      <GetOldTweets3.models.Tweet.Tweet object at 0x...      KRobert1953
# 3      <GetOldTweets3.models.Tweet.Tweet object at 0x...    RealtorKelli_
# 6      <GetOldTweets3.models.Tweet.Tweet object at 0x...     lobsterstyle
# 7      <GetOldTweets3.models.Tweet.Tweet object at 0x...     Mike83236577
# 9      <GetOldTweets3.models.Tweet.Tweet object at 0x...    Balkingpoints
# ...                                                  ...              ...
# 29994  <GetOldTweets3.models.Tweet.Tweet object at 0x...  richard19990185
# 29995  <GetOldTweets3.models.Tweet.Tweet object at 0x...   BobMoriartyABQ
# 29996  <GetOldTweets3.models.Tweet.Tweet object at 0x...     NellieBlithe
# 29997  <GetOldTweets3.models.Tweet.Tweet object at 0x...         ros_efra
# 29999  <GetOldTweets3.models.Tweet.Tweet object at 0x...         JMilesTV
#
#                                               tweet_text  \
# 0      Let's see. Fair? R III GGG HHH TTT. Fair juror...
# 3                                         #warren 2020!!
# 6      "Some people call you the elite—I call you my ...
# 7      #warren net worth $8.75M. Yea, a true hero for...
# 9      Mandatory #M4A. That is what polling is sharpl...
# ...                                                  ...
# 29994  #Warren and her #lies, has proved that she DOE...
# 29995  Always go with who you think is best. In my ca...
# 29996                        #Warren. She read his book.
# 29997  Mr.#BernieSanders is no dictator pos trump is,...
# 29999  Um. Warren supporter here. Still, um, supporti...
#
#                             date  \
# 0      2019-12-16 23:59:13+00:00
# 3      2019-12-16 23:36:57+00:00
# 6      2019-12-16 23:18:45+00:00
# 7      2019-12-16 23:14:42+00:00
# 9      2019-12-16 23:08:57+00:00
# ...                          ...
# 29994  2020-02-12 23:27:16+00:00
# 29995  2020-02-12 23:26:01+00:00
# 29996  2020-02-12 23:24:13+00:00
# 29997  2020-02-12 23:23:45+00:00
# 29999  2020-02-12 23:20:44+00:00
#
#                                                 hashtags  retweets  \
# 0      #Blumenthal #Murphy #Booker #Harris #Warren #B...         0
# 3                                                #warren         0
# 6      #Buttigieg #breaking #news #mayorpete #warren ...         2
# 7                                                #warren         0
# 9       #M4A #PublicOption #GOP #Bernie #Warren #Dem2020         0
# ...                                                  ...       ...
# 29994  #Warren #lies #JustStopWarrenJusStop #ShitLead...         0
# 29995                                            #Warren         0
# 29996                                            #Warren         0
# 29997                     #BernieSanders #Bernie #Warren         0
# 29999                                            #Warren         0
#
#       original_creator
# 0              thehill
# 3                  NPR
# 6       teddyschleifer
# 7                  ABC
# 9        JRubinBlogger
# ...                ...
# 29994         atensnut
# 29995    ProudResister
# 29996   DrJasonJohnson
# 29997   washingtonpost
# 29999   Whatapityonyou
#
# [13035 rows x 9 columns]

# %%
df = biden.append([bernie,trump,pete,war,mike])

# %%
#df.to_csv('/Users/Aifaz/Desktop/merged_candidates.csv')

# %%
df['username'].nunique()
# Out:
# 39591

# %%
bernie
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               3             3
# 1               4             4
# 2               6             6
# 3               7             7
# 4               9             9
# ...           ...           ...
# 14377        9983          9983
# 14378        9993          9993
# 14379        9995          9995
# 14380        9996          9996
# 14381        9999          9999
#
#                                             got_criteria         username  \
# 0      <GetOldTweets3.models.Tweet.Tweet object at 0x...     NWBernie2020
# 1      <GetOldTweets3.models.Tweet.Tweet object at 0x...    jakenotwalter
# 2      <GetOldTweets3.models.Tweet.Tweet object at 0x...     NWBernie2020
# 3      <GetOldTweets3.models.Tweet.Tweet object at 0x...  DavidMc67787096
# 4      <GetOldTweets3.models.Tweet.Tweet object at 0x...    SharonCarbine
# ...                                                  ...              ...
# 14377  <GetOldTweets3.models.Tweet.Tweet object at 0x...    jeffsguardian
# 14378  <GetOldTweets3.models.Tweet.Tweet object at 0x...   BHPanimalwatch
# 14379  <GetOldTweets3.models.Tweet.Tweet object at 0x...      MarkDickins
# 14380  <GetOldTweets3.models.Tweet.Tweet object at 0x...   Rob_theJacobin
# 14381  <GetOldTweets3.models.Tweet.Tweet object at 0x...  DoubleSpeakInDC
#
#                                               tweet_text  \
# 0      . @MSNBC @CNBC - #TheRevolutionWillNotBeTelevi...
# 1      We're going to get #BernieSanders, aren't we? ...
# 2      . @CNN - #TheRevolutionWillNotBeTelevised! CNN...
# 3      #BernieSanders #Bernie2020https://twitter.com/...
# 4      I agree. #BernieSanders is very similar to #Do...
# ...                                                  ...
# 14377  As you know, the second largest medical organi...
# 14378  If you can get elected for liking #BernieSande...
# 14379  Alexandria, I'm a fan of yours, but I despise ...
# 14380  Why is the #StillWithering crowd so deceitful ...
# 14381  #BernieSanders: honeymooned in the Soviet Unio...
#
#                             date  \
# 0      2020-02-19 23:59:25+00:00
# 1      2020-02-19 23:59:04+00:00
# 2      2020-02-19 23:58:33+00:00
# 3      2020-02-19 23:58:03+00:00
# 4      2020-02-19 23:57:56+00:00
# ...                          ...
# 14377  2020-01-22 11:10:13+00:00
# 14378  2020-01-22 10:48:17+00:00
# 14379  2020-01-22 10:44:21+00:00
# 14380  2020-01-22 10:43:52+00:00
# 14381  2020-01-22 10:38:23+00:00
#
#                                                 hashtags  retweets  \
# 0      #TheRevolutionWillNotBeTelevised #BernieSander...         0
# 1                                         #BernieSanders         0
# 2      #TheRevolutionWillNotBeTelevised #BernieSander...         0
# 3                        #BernieSanders #Bernie2020https         0
# 4      #BernieSanders #DonaldTrump #WhiteHouse #Sande...         0
# ...                                                  ...       ...
# 14377                  #M4A #BernieSanders #Medicare4All         1
# 14378                                     #BernieSanders         0
# 14379                                     #BernieSanders         2
# 14380                     #StillWithering #BernieSanders         0
# 14381                    #BernieSanders #Dems #Democrats         0
#
#       original_creator
# 0            AdamJoy42
# 1         TaraSetmayer
# 2            AdamJoy42
# 3           aaronjmate
# 4             Hopey_70
# ...                ...
# 14377      paladinette
# 14378        TomSteyer
# 14379              AOC
# 14380       Colettemai
# 14381    BernieSanders
#
# [14382 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'date', 'got_criteria', 'hashtags',
#        'original_creator', 'retweets', 'tweet_text', 'username'],
#       dtype='object')

# %%
# Find hashtags
import re

def find_hashtag(hasht):
    a_list = re.findall(r"#(\w+)", hasht)
    new_a_list = [x.lower() for x in a_list]
    return new_a_list

df['hashtags'] = df['tweet_text'].apply(find_hashtag)

# %%
# Find hashtags with warren
def find_warren(hasht):
    for name in hasht: 
        found = re.findall(r"(warren)", name)
        if found:
            for f in found: 
                return str(f)
        

df['warren'] = df['hashtags'].apply(find_warren)

# %%
# Find hashtags with pete
def find_pete(hasht):
    for name in hasht: 
        found = re.findall(r"(petebuttigieg)", name)
        if found:
            for f in found: 
                return str(f)
        

df['pete'] = df['hashtags'].apply(find_pete)

# Find hashtags with bernie

def find_bernie(hasht):
    for name in hasht: 
        found = re.findall(r"(berniesanders)", name)
        if found:
            for f in found: 
                return str(f)
        
df['berne'] = df['hashtags'].apply(find_bernie)

def find_biden(hasht):
    for name in hasht: 
        found = re.findall(r"(joebiden)", name)
        if found:
            for f in found: 
                return str(f)
        

df['biden'] = df['hashtags'].apply(find_biden)

def find_bloomberg(hasht):
    for name in hasht: 
        found = re.findall(r"(bloomberg)", name)
        if found:
            for f in found: 
                return str(f)
        

df['bloomberg'] = df['hashtags'].apply(find_bloomberg)
# df['bloomberg']

def find_trump(hasht):
    for name in hasht: 
        found = re.findall(r"(trump)", name)
        if found:
            for f in found: 
                return str(f)
        

df['trump'] = df['hashtags'].apply(find_trump)
# df['bloomberg']

# %%
# Create politican dataframe, choose the columns to include and rename the columns to politician

warren = df[df['warren']=='warren'][['username', 'warren']].rename(columns={"warren": "politician"})


pete = df[df['pete']=='petebuttigieg'][['username', 'pete']].rename(columns={"pete": "politician"})

bernie = df[df['berne']=='berniesanders'][['username', 'berne']].rename(columns={"berne": "politician"})

biden = df[df['biden']=='joebiden'][['username', 'biden']].rename(columns={"biden": "politician"})

bloom = df[df['bloomberg']=='bloomberg'][['username', 'bloomberg']].rename(columns={"bloomberg": "politician"})
trump = df[df['trump']=='trump'][['username', 'trump']].rename(columns={"trump": "politician"})

df_total = warren.append([pete, bernie, biden, bloom,trump])

# %%
df_total.drop_duplicates(inplace=True)

# %%
df_total['politician'].value_counts()
# Out:
# warren           14036
# joebiden          9676
# trump             9555
# berniesanders     7589
# bloomberg         5108
# petebuttigieg     3338
# Name: politician, dtype: int64

# %%
df_total = df_total[df_total['username'] != 'AAA']

# %% [markdown]
# # NetworkX

# %% [markdown]
# Bernie

# %%
df_bernie = df[df['berne'] == 'berniesanders']
name_list = df_bernie['original_creator'].value_counts().index.values[:200]

def name_in_list(username): 
    if username in name_list: 
        return 1 
    return 0 

df_bernie['degrees'] = df_bernie['original_creator'].map(name_in_list)
df_bernie = df_bernie[df_bernie['degrees'] == 1]



# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df_bernie,
    source = 'username', 
    target = 'original_creator',
    create_using = nx.DiGraph())

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, node_color = 'blue')
plt.title('Pete Buttigieg', size=15)
plt.show()

# %% [markdown]
# Joe Biden

# %%
df_biden = df[df['biden'] == 'joebiden']
name_list = df_biden['original_creator'].value_counts().index.values[:200]

def name_in_list(username): 
    if username in name_list: 
        return 1 
    return 0 

df_biden['degrees'] = df_biden['original_creator'].map(name_in_list)
df_biden = df_biden[df_biden['degrees'] == 1]



# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df_biden,
    source = 'username', 
    target = 'original_creator',
    create_using = nx.DiGraph())

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, node_color = 'blue')
plt.title('Pete Buttigieg', size=15)
plt.show()

# %% [markdown]
# Warren

# %%
df_warren = df[df['warren'] == 'warren']
name_list = df_warren['original_creator'].value_counts().index.values[:200]

def name_in_list(username): 
    if username in name_list: 
        return 1 
    return 0 

df_warren['degrees'] = df_warren['original_creator'].map(name_in_list)
df_warren = df_warren[df_warren['degrees'] == 1]



# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df_warren,
    source = 'username', 
    target = 'original_creator',
    create_using = nx.DiGraph())

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, node_color = 'blue')
plt.title('Pete Buttigieg', size=15)
plt.show()

# %% [markdown]
# pete

# %%
df_pete = df[df['pete'] == 'petebuttigieg']
name_list = df_pete['original_creator'].value_counts().index.values[:200]

def name_in_list(username): 
    if username in name_list: 
        return 1 
    return 0 

df_pete['degrees'] = df_pete['original_creator'].map(name_in_list)
df_pete = df_pete[df_pete['degrees'] == 1]



# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df_pete,
    source = 'username', 
    target = 'original_creator',
    create_using = nx.DiGraph())

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, node_color = 'blue')
plt.title('Pete Buttigieg', size=15)
plt.show()

# %% [markdown]
# Bloomberg

# %%
df_bloom = df[df['bloomberg'] == 'bloomberg']
name_list = df_bloom['original_creator'].value_counts().index.values[:200]

def name_in_list(username): 
    if username in name_list: 
        return 1 
    return 0 

df_bloom['degrees'] = df_bloom['original_creator'].map(name_in_list)
df_bloom = df_bloom[df_bloom['degrees'] == 1]



# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df_bloom,
    source = 'username', 
    target = 'original_creator',
    create_using = nx.DiGraph())

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, node_color = 'blue')
plt.title('Bloomberg', size=15)
plt.show()

# %% [markdown]
# TRUMP

# %%
df_trump = df[df['trump'] == 'trump']
name_list = df_trump['original_creator'].value_counts().index.values[:200]

def name_in_list(username): 
    if username in name_list: 
        return 1 
    return 0 

df_trump['degrees'] = df_trump['original_creator'].map(name_in_list)
df_trump = df_trump[df_trump['degrees'] == 1]



# Create retweet network from edgelist
network = nx.from_pandas_edgelist(
    df_trump,
    source = 'username', 
    target = 'original_creator',
    create_using = nx.DiGraph())

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 15))
nx.draw(network, edge_color ="black", linewidths=0.3, node_size=50, node_color = 'blue')
plt.title('Bloomberg', size=15)
plt.show()
