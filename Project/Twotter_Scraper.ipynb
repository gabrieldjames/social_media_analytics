# %%
pip install GetOldTweets3
# Out:
# Collecting GetOldTweets3
#   Downloading https://files.pythonhosted.org/packages/ed/f4/a00c2a7c90801abc875325bb5416ce9090ac86d06a00cc887131bd73ba45/GetOldTweets3-0.0.11-py3-none-any.whl
# Requirement already satisfied: lxml>=3.5.0 in /Users/vinaykhanijow/.conda/envs/mypython3/lib/python3.7/site-packages (from GetOldTweets3) (4.4.1)
# Collecting pyquery>=1.2.10 (from GetOldTweets3)
#   Downloading https://files.pythonhosted.org/packages/78/43/95d42e386c61cb639d1a0b94f0c0b9f0b7d6b981ad3c043a836c8b5bc68b/pyquery-1.4.1-py2.py3-none-any.whl
# Collecting cssselect>0.7.9 (from pyquery>=1.2.10->GetOldTweets3)
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 cssselect-1.1.0 pyquery-1.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import GetOldTweets3 as got
import pandas as pd 

def get_twitter_info():
    tweet_df['username'] = tweet_df["got_criteria"].apply(lambda x: x.username)
    tweet_df["tweet_text"] = tweet_df["got_criteria"].apply(lambda x: x.text)
    tweet_df["date"] = tweet_df["got_criteria"].apply(lambda x: x.date)
    tweet_df["hashtags"] = tweet_df["got_criteria"].apply(lambda x: x.hashtags)
    

keyword = "#elizabethwarren"
oldest_date = "2019-01-01"    
newest_date = "2020-02-20"
number_tweets = 10000

tweet_criteria = got.manager.TweetCriteria().setQuerySearch(keyword)\
                                            .setSince(oldest_date)\
                                            .setUntil(newest_date)\
                                            .setMaxTweets(number_tweets)

tweet_df = pd.DataFrame({'got_criteria':got.manager.TweetManager.getTweets(tweet_criteria)})

get_twitter_info()


# Export to a csv
# tweet_df.to_csv("Twitter_data.csv")

# %%
tweet_df
# Out:
#                                            got_criteria        username  \
# 0     <GetOldTweets3.models.Tweet.Tweet object at 0x...          Loftii
# 1     <GetOldTweets3.models.Tweet.Tweet object at 0x...      AngelaZito
# 2     <GetOldTweets3.models.Tweet.Tweet object at 0x...       ludlow163
# 3     <GetOldTweets3.models.Tweet.Tweet object at 0x...  Charles_Rengel
# 4     <GetOldTweets3.models.Tweet.Tweet object at 0x...         str12ng
# ...                                                 ...             ...
# 9995  <GetOldTweets3.models.Tweet.Tweet object at 0x...  TeoMangialetti
# 9996  <GetOldTweets3.models.Tweet.Tweet object at 0x...    Indiana_Anne
# 9997  <GetOldTweets3.models.Tweet.Tweet object at 0x...    JusticeJimmy
# 9998  <GetOldTweets3.models.Tweet.Tweet object at 0x...    whisperwatch
# 9999  <GetOldTweets3.models.Tweet.Tweet object at 0x...         atticvs
#
#                                              tweet_text  \
# 0     #BernieSanders #SouthCarolinaPrimary #BernieSa...
# 1         #ElizabethWarren #PresidentWarren #Warren2020
# 2     I pledge to vote for Elizabeth Warren in 2020!...
# 3     Yet another major reason why #ElizabethWarren ...
# 4     1 - A reminder why this administration needs t...
# ...                                                 ...
# 9995  #ElizabethWarren literally took on John Robert...
# 9996                                  #ElizabethWarren
# 9997  #ElizabethWarren Wants Criminal Penalties For ...
# 9998  Welp. ¯\_(ツ)_/¯ Dems learned nothing from #Eli...
# 9999  #ElizabethWarren, if elected, will let a 9 yr ...
#
#                           date  \
# 0    2020-02-19 23:59:01+00:00
# 1    2020-02-19 23:58:09+00:00
# 2    2020-02-19 23:57:59+00:00
# 3    2020-02-19 23:55:04+00:00
# 4    2020-02-19 23:54:52+00:00
# ...                        ...
# 9995 2020-01-31 06:44:25+00:00
# 9996 2020-01-31 06:24:38+00:00
# 9997 2020-01-31 06:23:32+00:00
# 9998 2020-01-31 06:19:28+00:00
# 9999 2020-01-31 06:15:25+00:00
#
#                                                hashtags
# 0     #BernieSanders #SouthCarolinaPrimary #BernieSa...
# 1         #ElizabethWarren #PresidentWarren #Warren2020
# 2         #PresidentWarren #Warren2020 #ElizabethWarren
# 3         #ElizabethWarren #Warren2020 #WarrenForTheWin
# 4           #Warren2020 #WinWithWarren #ElizabethWarren
# ...                                                 ...
# 9995  #ElizabethWarren #Warren2020 #CORRUPTION #Corr...
# 9996                                   #ElizabethWarren
# 9997                                   #ElizabethWarren
# 9998                #ElizabethWarren #reparations #ADOS
# 9999        #ElizabethWarren #Trump2020LandslideVictory
#
# [10000 rows x 5 columns]

# %%
# Export to a csv
tweet_df.to_csv("Twitter_data.csv")

# %%
tweet_df.username.value_counts()
# Out:
# roots4bernie       220
# SPOTTEDDOG129      105
# Loftii              81
# madamyez            71
# SDSunchaser         68
#                   ...
# NoMasPorFavor59      1
# lianniRep            1
# TrueTexasNews        1
# RunAJRun             1
# Iq187                1
# Name: username, Length: 5507, dtype: int64

# %%
import GetOldTweets3 as got
import pandas as pd 

def get_twitter_info():
    tweet_df1['username'] = tweet_df1["got_criteria"].apply(lambda x: x.username)
    tweet_df1["tweet_text"] = tweet_df1["got_criteria"].apply(lambda x: x.text)
    tweet_df1["date"] = tweet_df1["got_criteria"].apply(lambda x: x.date)
    tweet_df1["hashtags"] = tweet_df1["got_criteria"].apply(lambda x: x.hashtags)
    

keyword = "#warren2020"
oldest_date = "2019-01-01"    
newest_date = "2020-02-20"
number_tweets = 10000

tweet_criteria = got.manager.TweetCriteria().setQuerySearch(keyword)\
                                            .setSince(oldest_date)\
                                            .setUntil(newest_date)\
                                            .setMaxTweets(number_tweets)

tweet_df1 = pd.DataFrame({'got_criteria':got.manager.TweetManager.getTweets(tweet_criteria)})

get_twitter_info()


# Export to a csv
# tweet_df.to_csv("Twitter_data.csv")

# %%
tweet_df1
# Out:
#                                            got_criteria        username  \
# 0     <GetOldTweets3.models.Tweet.Tweet object at 0x...   LadyRiverdale
# 1     <GetOldTweets3.models.Tweet.Tweet object at 0x...          Loftii
# 2     <GetOldTweets3.models.Tweet.Tweet object at 0x...    leftcoaster4
# 3     <GetOldTweets3.models.Tweet.Tweet object at 0x...  XimenaLevander
# 4     <GetOldTweets3.models.Tweet.Tweet object at 0x...        solarcat
# ...                                                 ...             ...
# 9995  <GetOldTweets3.models.Tweet.Tweet object at 0x...      nancy_annn
# 9996  <GetOldTweets3.models.Tweet.Tweet object at 0x...  thismamatweets
# 9997  <GetOldTweets3.models.Tweet.Tweet object at 0x...     lisasharper
# 9998  <GetOldTweets3.models.Tweet.Tweet object at 0x...      CSojourner
# 9999  <GetOldTweets3.models.Tweet.Tweet object at 0x...      CSojourner
#
#                                              tweet_text  \
# 0     Bernie hasn't won anything yet. He won't win o...
# 1     #BernieSanders #SouthCarolinaPrimary #BernieSa...
# 2     This seems@like the correct progression: #Wher...
# 3     Elizabeth Warren is a corrupt billionaire’s wo...
# 4                            #Warren2020 #WhereIsWarren
# ...                                                 ...
# 9995                                       #Warren2020
# 9996  Join me in supporting Elizabeth Warren via @ac...
# 9997  .@EWarren is 3rd in the delegate count right n...
# 9998                                       #Warren2020
# 9999  #Warren2020 for #SocialJustice and #EconomicJu...
#
#                           date  \
# 0    2020-02-19 23:59:25+00:00
# 1    2020-02-19 23:59:01+00:00
# 2    2020-02-19 23:58:59+00:00
# 3    2020-02-19 23:58:20+00:00
# 4    2020-02-19 23:58:17+00:00
# ...                        ...
# 9995 2020-02-17 14:16:56+00:00
# 9996 2020-02-17 14:16:39+00:00
# 9997 2020-02-17 14:15:42+00:00
# 9998 2020-02-17 14:15:26+00:00
# 9999 2020-02-17 14:14:54+00:00
#
#                                                hashtags
# 0                                #BernieBro #Warren2020
# 1     #BernieSanders #SouthCarolinaPrimary #BernieSa...
# 2            #WheresWarren #Warren2020 #PresidentWarren
# 3                            #Warren2020 #WinWithWarren
# 4                            #Warren2020 #WhereIsWarren
# ...                                                 ...
# 9995                                        #Warren2020
# 9996                                        #Warren2020
# 9997                                        #Warren2020
# 9998                                        #Warren2020
# 9999        #Warren2020 #SocialJustice #EconomicJustice
#
# [10000 rows x 5 columns]

# %%
tweet_df1.username.value_counts()
# Out:
# CaliLiliIndies    68
# shesnottrump      51
# Janis454          45
# LadyRiverdale     44
# LauraManos        40
#                   ..
# _mildlyamusing     1
# zerocoolgirl13     1
# NmDominique        1
# susanssh           1
# KatieC1212         1
# Name: username, Length: 4023, dtype: int64

# %%
warren_csv=tweet_df.append(tweet_df1)

# %%
warren_csv
# Out:
#                                            got_criteria        username  \
# 0     <GetOldTweets3.models.Tweet.Tweet object at 0x...          Loftii
# 1     <GetOldTweets3.models.Tweet.Tweet object at 0x...      AngelaZito
# 2     <GetOldTweets3.models.Tweet.Tweet object at 0x...       ludlow163
# 3     <GetOldTweets3.models.Tweet.Tweet object at 0x...  Charles_Rengel
# 4     <GetOldTweets3.models.Tweet.Tweet object at 0x...         str12ng
# ...                                                 ...             ...
# 9995  <GetOldTweets3.models.Tweet.Tweet object at 0x...      nancy_annn
# 9996  <GetOldTweets3.models.Tweet.Tweet object at 0x...  thismamatweets
# 9997  <GetOldTweets3.models.Tweet.Tweet object at 0x...     lisasharper
# 9998  <GetOldTweets3.models.Tweet.Tweet object at 0x...      CSojourner
# 9999  <GetOldTweets3.models.Tweet.Tweet object at 0x...      CSojourner
#
#                                              tweet_text  \
# 0     #BernieSanders #SouthCarolinaPrimary #BernieSa...
# 1         #ElizabethWarren #PresidentWarren #Warren2020
# 2     I pledge to vote for Elizabeth Warren in 2020!...
# 3     Yet another major reason why #ElizabethWarren ...
# 4     1 - A reminder why this administration needs t...
# ...                                                 ...
# 9995                                       #Warren2020
# 9996  Join me in supporting Elizabeth Warren via @ac...
# 9997  .@EWarren is 3rd in the delegate count right n...
# 9998                                       #Warren2020
# 9999  #Warren2020 for #SocialJustice and #EconomicJu...
#
#                           date  \
# 0    2020-02-19 23:59:01+00:00
# 1    2020-02-19 23:58:09+00:00
# 2    2020-02-19 23:57:59+00:00
# 3    2020-02-19 23:55:04+00:00
# 4    2020-02-19 23:54:52+00:00
# ...                        ...
# 9995 2020-02-17 14:16:56+00:00
# 9996 2020-02-17 14:16:39+00:00
# 9997 2020-02-17 14:15:42+00:00
# 9998 2020-02-17 14:15:26+00:00
# 9999 2020-02-17 14:14:54+00:00
#
#                                                hashtags
# 0     #BernieSanders #SouthCarolinaPrimary #BernieSa...
# 1         #ElizabethWarren #PresidentWarren #Warren2020
# 2         #PresidentWarren #Warren2020 #ElizabethWarren
# 3         #ElizabethWarren #Warren2020 #WarrenForTheWin
# 4           #Warren2020 #WinWithWarren #ElizabethWarren
# ...                                                 ...
# 9995                                        #Warren2020
# 9996                                        #Warren2020
# 9997                                        #Warren2020
# 9998                                        #Warren2020
# 9999        #Warren2020 #SocialJustice #EconomicJustice
#
# [20000 rows x 5 columns]

# %%
warren_csv.to_csv("warren.csv")
